# %% [markdown]
# #### Importing relevant packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from bs4 import BeautifulSoup #requires pip install
import requests #requires pip install

# %%
#Test zoopla scraper
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import time
from bs4 import BeautifulSoup #requires pip install
import requests
import re
from re import sub
from decimal import Decimal
import io

# Convert price string into a numerical value
def to_num(price):
    value = Decimal(sub(r'[^\d.]', '', price))
    return float(value)

def is_dropped(money):
    for i in range(len(money)):
        if(money[i] != '£' and money[i] != ',' and (not money[i].isdigit())):
            return True
    return False

# %%
#set up the the scraper
url = 'https://www.zoopla.co.uk/for-sale/property/london/?page_size=25&q=london&radius=0&results_sort=newest_listings&pn='

map = {}
id = 0

#set max_pages to 2 for test purposes
max_pages = 3

# time.sleep(10)
start = time.time()

for p in range(max_pages):
    cur_url = url + str(p + 1)

    print("Scraping page: %d" % (p + 1))
    #print(cur_url)
    html_text = requests.get(cur_url).text
    soup = BeautifulSoup(html_text, 'lxml')

    ads = soup.find_all('div', class_ = 'css-wfndrn-StyledContent e2uk8e18')
    page_nav = soup.find_all('a', class_ = 'css-slm4qd-StyledPaginationLink eaoxhri5')

    if(len(page_nav) == 0):
        print("max page number: %d" % (p))
        # end = time.time()
        # print(end - start)
        break

    for k in range(len(ads)):
        ad = ads[k]

        #find link and ID ('identifier' in the link acts as a unique id for the ad)
        link = ad.find('a', class_ = 'e2uk8e4 css-gl9725-StyledLink-Link-FullCardLink e33dvwd0')

        #find section for address
        address = ad.find('p', class_ = 'css-wfe1rf-Text eczcs4p0').text

        #find price information
        price = ad.find('p', class_ = 'css-18tfumg-Text eczcs4p0').text

        # if the price is valid or not, if not we do not consider this ad
        if(is_dropped(price)): continue

        #find public transport information
        subway_section = ad.find('div', class_ = 'css-braguw-TransportWrapper e2uk8e28')
        subway_information = subway_section.find_all('p', class_ = 'css-wfe1rf-Text eczcs4p0')

        #skip ads that only contain information of train station
        outlier = subway_section.find('span', class_ = 'e1uy4ban0 css-10ibqwe-StyledIcon-Icon e15462ye0')
        if(outlier['data-testid'] == 'national_rail_station'): continue

        #find section for bedroom, bathroom and living room information (room numbers)
        feature_section = ad.find('div', class_ = 'css-58bgfg-WrapperFeatures e2uk8e15')

        #find all information available for room numbers
        category = feature_section.find_all('div', class_ = 'ejjz7ko0 css-l6ka86-Wrapper-IconAndText e3e3fzo1')

        #assign id
        ad_id = link['href'] #returns url snippet with identifier from the url
        ad_id= ad_id.split("?")[0] #split by '?' ans '/' and apply index to retain only identifier number
        ad_id= ad_id.split("/")[3]

        if(ad_id in map): continue
        map[ad_id] = {}

        #assign link
        link = 'https://www.zoopla.co.uk/' + link['href']
        map[ad_id]["link"] = link

        #assign address
        map[ad_id]["address"] = address

        #assign bedroom nr
        try:
            map[ad_id]["room_nr"] = category[0].text
        except IndexError:
        #insert None value if index is not found
            map[ad_id]["room_nr"] = 'None'
            #print("Feature not listed")

        #assign bathroom nr
        try:
            map[ad_id]["bath_nr"] = category[1].text
        except IndexError:
        #insert None value if index is not found
            map[ad_id]["bath_nr"] = 'None'
            #print("Feature not listed")

        #assign living room nr
        try:
            map[ad_id]["living_nr"] = category[2].text
        except IndexError:
        #insert None value if index is not found
            map[ad_id]["living_nr"] = 'None'
            #print("Feature not listed")

        #assign price
        map[ad_id]["price"] = to_num(price)

        #assign subway station and distance to it
        s = subway_information[0].text
        x = s.split(' miles ')
        if len(x) == 1: continue
        map[ad_id]["distance"] = float(x[0])
        map[ad_id]["subway_station"] = x[1]

print("Scraping task finished")

#transform to dict to list
result = []
cur_row = 0
for cur_id in map.keys():
    link = map[cur_id]["link"]
    cur_price = map[cur_id]["price"]
    cur_bedroom = map[cur_id]["room_nr"]
    cur_bathroom = map[cur_id]["bath_nr"]
    cur_living = map[cur_id]["living_nr"]
    cur_address = map[cur_id]["address"]
    cur_distance = map[cur_id]["distance"]
    cur_subway_station = map[cur_id]["subway_station"]
    result.append([])
    result[cur_row].append(str(cur_id))
    result[cur_row].append(str(link))
    result[cur_row].append(str(cur_price))
    result[cur_row].append(str(cur_bedroom))
    result[cur_row].append(str(cur_bathroom))
    result[cur_row].append(str(cur_living))
    result[cur_row].append(str(cur_address))
    result[cur_row].append(str(cur_distance))
    result[cur_row].append(str(cur_subway_station))
    cur_row += 1

#transform to dataframe
df = pd.DataFrame(result, columns = ["ad_id", "link", "price", "bedrooms", "bathrooms", "living_rooms", "address", "distance", "subway_station"])
df
# Out:
# Scraping page: 1
# max page number: 0
# Scraping task finished
# Empty DataFrame
# Columns: [ad_id, link, price, bedrooms, bathrooms, living_rooms, address, distance, subway_station]
# Index: []

# %%
#Dexter scraper:

# Import packages
import pandas as pd
import numpy as np
import datetime
from bs4 import BeautifulSoup #requires pip install
import requests #requires pip install
import re
import time

import io
# document time
time_started = str(datetime.datetime.now()).replace(" ","_").replace(":","-")[0:19]
## Define list of subway stations
Underground_lines = ['Bakerloo', 'Central', 'Circle', 'District', 'DLR', 'Hammersmith & City',
                 'Jubilee', 'Metropolitan', 'Northern', 'Piccadilly', 'Victoria', 'Waterloo & City']

## Function to extract characteristics on each ad from the main webpage
def feature_extract(html_text):

    soup = BeautifulSoup(html_text, 'lxml')

    ## Parse for the different divisions within the add

    # ads = soup.find_all('div', class_ = 'result-content') #searches for 'div' and is filtered by the CSS-snippet
    ads = soup.find_all('li', class_ = 'result item for-sale infinite-item')#searches for 'div' and is filtered by the CSS-snippet
    ## Set-up for the loop
    results = {} #create nested dictionary to store the results
    id_ad = 0 #insert ad_ID to distinguish between each ad

    ## Loop across all ads
    for k in range(len(ads)):
        ad = ads[k]
        id_ad += 1
        results[id_ad] = {}

        ## Extracting features from the ad
        name = ad.find('h3').a.contents[0]
        try:
            price = ad.find('span', class_ = 'price-qualifier').text #catches the price WITHIN one ad
        except:
            continue
        address = ad.find('span', class_ = 'address-area-post').text

        # Number of bedrooms extracted from string
        try:
            bedrooms = ad.find('li', class_ = 'Bedrooms').text
        except:
            continue
        bedrooms_nbr = int(bedrooms.split()[0])

        # Number of bedrooms extracted from string
        bathrooms_str = str(ad.find('li',class_ = 'Bathrooms'))
        bathrooms_nbr = re.findall(r'\d+', bathrooms_str)
        bathrooms_nbr2 = int(bathrooms_nbr[0] if len(bathrooms_nbr)!= 0  else 0)

        # Number of bedrooms extracted from string
        reception_str = str(ad.find('li',class_ = 'Receptions'))
        reception_nbr = re.findall(r'\d+', reception_str)
        reception_nbr2 = int(reception_nbr[0] if len(reception_nbr)!= 0  else 1)

        link = ad.find('h3').a.get("href")

        ad_identification = ads[k]['data-property-id']

        # Create dictionary of results per ad id
        results[id_ad]['ad_identification'] = ad_identification
        results[id_ad]["street_name"] = name
        results[id_ad]["price"] = price
        results[id_ad]["address"] = address
        results[id_ad]["bedrooms"] = bedrooms_nbr
        results[id_ad]["bathrooms"] = bathrooms_nbr2
        results[id_ad]["reception"] = reception_nbr2
        results[id_ad]["link"] = ("https://www.dexters.co.uk" + link)

        # Create dataframe from dictionary of results
        df_houses = pd.DataFrame.from_dict(results, orient='index')

    return df_houses

## Function to create list of pages base on url and number of iterations desired
def page_list(string, iterations):
    pages_list = []
    for i in range(iterations):
        pages_list.append(string + str(i+1))

    return pages_list

## Function to get the maximum number of listing on Dexter's website
def page_max(url):
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'lxml')
    amount = soup.find('span', class_ = 'marker-count has-results').text
    amount_num = re.sub('\D', '', amount)
    return int(amount_num)

## Function to launch scrapper on a specific webpage with number of pages to scrap
def pages_scrap(main_page, iter_page, pages):
    max_pages = (page_max(main_page)/18)
    list_of_pages = page_list(iter_page, pages) # Create list of pages to scrape
    df_list = [] #Create list of dataframes to be concatenated by the end of the loop

    # Loop through all pages to create the different dataframes
    for page in list_of_pages:
        html_page = requests.get(page)
        html_page.encoding = 'utf-8'
        page = html_page.text
        df_ads = feature_extract(page)
        df_list.append(df_ads)

    # Concatenate the different dataframes
    df_results = pd.concat(df_list)
    df_results = df_results.drop_duplicates()
    df_results = df_results.reset_index(drop=True)

    print('Remaining number of page: ', int(max_pages - pages) )

    return df_results
# 1.2 Subway related functions

## Function to extract subway info list from a house webpage on dexter
def get_info_subway(link):
    html_text = requests.get(link).text
    soup = BeautifulSoup(html_text, 'lxml')
    subway = soup.find('ul', class_ = 'list-information').text

    return subway

## Function to get list of values for subway distances with string
def sub_values(string):
    split = string.split('\n')
    list_1 = list(filter(None, split))

    list_2 = []
    for i in list_1:
        x = i.split('-')
        list_2.append(x)

    list_3 = [item.strip() for sublist in list_2 for item in sublist]
    list_4 = list_3[0:3]

    return list_3

## Function to get the closest stop on the tube if any
def closest_line(list_of_lines):
    j = 0
    nearby_data = []
    for i in range(len(list_of_lines)):
        if list_of_lines[i] == 'London Underground' or list_of_lines[i] in Underground_lines and (j != 1 and i!=0):
            if (' ' in list_of_lines[i-2]) == False :
                nearby_data.append(list_of_lines[i-3])
                nearby_data.append(list_of_lines[i-2])
                nearby_data.append(list_of_lines[i-1])
                nearby_data.append(list_of_lines[i])
                j = 1

                nearby_data[0] = (' '.join(nearby_data[0:2]))
                del nearby_data[1]

            else:
                nearby_data.append(list_of_lines[i-2])
                nearby_data.append(list_of_lines[i-1])
                nearby_data.append(list_of_lines[i])
                j = 1

    return nearby_data

## Function to populate datafrmae with closest tube stop name, distance, and related tube line
def subway_per_house(df):
    #Create new empty (NaN) columns in the existing dataframe
    df = df.reindex(columns = df.columns.tolist() + ['subway_station','distance','tube_line'])

    #Loop through all lines of dataframe
    for i in range(len(df)):
        x = df['link'].iloc[i] #Get link of house page to scrape
        subs = get_info_subway(x) #Extract tube line info
        subs_2 = sub_values(subs) #Get list of subway station and distance
        subs_3 = closest_line(subs_2) #Extract closest tube station only

        # Populate dataframe if a tubeway station has been found or not
        if len(subs_3)!= 0:
            df['subway_station'].iloc[i] = subs_3[0]
            df['distance'].iloc[i] = subs_3[1]
            df['tube_line'].iloc[i] = subs_3[2]
        else:
            df['subway_station'].iloc[i] = np.NaN
            df['distance'].iloc[i] = np.NaN
            df['tube_line'].iloc[i] = np.NaN

    df = df.astype(str)

    return df

#Functions to clean subway output
def get_tube_dist(string):
    string_m = string.split(' ')
    num_val = string_m[-1]

    return num_val
def strip_tube(string):
    string_m = string.split(' ')
    string_m = string_m[:-1]
    string_m = ' '.join(string_m)

    return string_m
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

## Function to clean subway stops when too many words in the string
def clean_tube_stop_string(string):
    forbiddden_words = ['London Overground', 'Railway', 'Network Rail', 'Tramlink']
    count_forbidden = 0

    for j in forbiddden_words:
        if count_forbidden == 0:
            if j in string:
                string_update = string.split()[-1]
                count_forbidden = 1
            else:
                string_update = string

    return(string_update)

## Function to input tube distance into the right column when value is in 'tube_stop'
def clean_tube_dist(df):
    df['distance'] = df['distance'].astype('str')

    errors  = df[df.loc[:, 'distance'].map(hasNumbers) == False].copy()
    errors_2 = errors.loc[errors['subway_station'] != 'NaN'].copy()
    errors_2.loc[:, 'distance'] = errors_2.loc[:, 'subway_station'].map(get_tube_dist)
    errors_2.loc[:, 'subway_station'] = errors_2.loc[:, 'subway_station'].map(strip_tube)
    errors_2

    #Create copy of original df for modification
    df_copy = df.copy()

    # replace values in final df
    for i in errors_2.index:
        df_copy.loc[i] = errors_2.loc[i]

    return df_copy

## Functions to deal with Victoria tube stops (Victoria being both a tube stop and a tube line)
def victoria_clean_stop(string):
    str_vic = 'Victoria'
    str_check = string.split()
    if str_check[0] == 'Victoria':
        str_return = str_check[1]
    else:
        str_return = str_vic

    return str_return
def clean_tube_victoria(df):
    df['subway_station'] = df['subway_station'].astype('str')

    errors  = df[df['subway_station'].str.contains('Victoria')].copy()

    errors.loc[:, 'subway_station'] = errors.loc[:, 'subway_station'].map(victoria_clean_stop)

    #Create copy of original df for modification
    df_copy = df.copy()

    # Replace values in final df
    for i in errors.index:
        df_copy.loc[i] = errors.loc[i]

    return df_copy

## Final cleaning function to apply previous cleaning on 'tube_stop' and 'tube_dist' for the whole dataframe
def clean_tube_stop(df):
    df_2 = df.copy()
    df_2 = clean_tube_dist(df_2)
    df_2['subway_station'] = df_2['subway_station'].astype('str')
    df_2['subway_station'] = df_2['subway_station'].map(clean_tube_stop_string)

    df_2 = clean_tube_victoria(df_2)
    # #Keep the ID of the add as index or not


    return df_2

dexter_list_1 = pages_scrap('https://www.dexters.co.uk/property-sales/properties-for-sale-in-london',
                            'https://www.dexters.co.uk/property-sales/properties-for-sale-in-london/page-', 1)


## Fetch subway related information from the previous dataframe
output_list = subway_per_house(dexter_list_1)

output_list

cleaned = clean_tube_stop(output_list)
cleaned
# Out:
# Remaining number of page:  260
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#    ad_identification        street_name        price               address  \
# 0             151907     Lancaster Gate  £23,000,000         Hyde Park, W2
# 1             124656    Wilton Crescent  £19,500,000       Belgravia, SW1X
# 2             138546    Whitehall Place   £9,250,000       Whitehall, SW1A
# 3             143179   Old Queen Street   £9,250,000     Westminster, SW1H
# 4             138545    Whitehall Place   £9,000,000       Whitehall, SW1A
# 5             138542    Whitehall Place   £8,500,000       Whitehall, SW1A
# 6             155928     Radnor Terrace   £6,500,000       Kensington, W14
# 7             138689       Queen Street   £6,000,000          Mayfair, W1J
# 8             138690       Queen Street   £6,000,000          Mayfair, W1J
# 9             145085          Hall Road   £5,995,000   St John's Wood, NW8
# 10            159717      Ladbroke Road   £5,500,000     Notting Hill, W11
# 11            156629  Fairhazel Gardens   £5,495,000  South Hampstead, NW6
# 12            157041         Kings Road   £5,000,000        Richmond, TW10
# 13            159188  Philbeach Gardens   £5,000,000      Earls Court, SW5
# 14            151165       Green Street   £4,950,000          Mayfair, W1K
#
#    bedrooms bathrooms reception  \
# 0        60         0         1
# 1         5         5         2
# 2         3         3         1
# 3         5         4         6
# 4         3         3         2
# 5         2         2         2
# 6         4         4         1
# 7         3         3         2
# 8         3         3         1
# 9         5         5         5
# 10        5         4         2
# 11        5         5         3
# 12        8         3         3
# 13        7         3         3
# 14        3         3         2
#
#                                                  link        subway_station  \
# 0   https://www.dexters.co.uk/property-for-sale/pr...        Lancaster Gate
# 1   https://www.dexters.co.uk/property-for-sale/ho...         Knightsbridge
# 2   https://www.dexters.co.uk/property-for-sale/fl...         Charing Cross
# 3   https://www.dexters.co.uk/property-for-sale/ho...       St.James's Park
# 4   https://www.dexters.co.uk/property-for-sale/fl...         Charing Cross
# 5   https://www.dexters.co.uk/property-for-sale/fl...         Charing Cross
# 6   https://www.dexters.co.uk/property-for-sale/fl...  Kensington (Olympia)
# 7   https://www.dexters.co.uk/property-for-sale/fl...            Green Park
# 8   https://www.dexters.co.uk/property-for-sale/fl...            East India
# 9   https://www.dexters.co.uk/property-for-sale/pr...            Maida Vale
# 10  https://www.dexters.co.uk/property-for-sale/pr...     Notting Hill Gate
# 11  https://www.dexters.co.uk/property-for-sale/pr...         Finchley Road
# 12  https://www.dexters.co.uk/property-for-sale/pr...              Richmond
# 13  https://www.dexters.co.uk/property-for-sale/ho...          Earl's Court
# 14  https://www.dexters.co.uk/property-for-sale/fl...           Marble Arch
#
#    distance   tube_line
# 0     0.26m     Central
# 1     0.22m  Piccadilly
# 2     0.12m    Bakerloo
# 3     0.16m      Circle
# 4     0.12m    Bakerloo
# 5     0.12m    Bakerloo
# 6     0.22m    District
# 7     0.18m     Jubilee
# 8     0.17m         DLR
# 9     0.22m    Bakerloo
# 10    0.14m     Central
# 11    0.19m     Jubilee
# 12    0.41m    District
# 13    0.27m    District
# 14     0.1m     Central

# %%
cleaned.shape
# Out:
# (15, 11)

# %%
epc_url='https://find-energy-certificate.digital.communities.gov.uk/find-a-certificate/search-by-street-name-and-town?street_name='
town_url='&town=London'
street_name='Bramwell Way'
url_street_name=street_name.replace(' ','+')
url_street_name
final_epc_url=epc_url+url_street_name+town_url
final_epc_url
# Out:
# 'https://find-energy-certificate.digital.communities.gov.uk/find-a-certificate/search-by-street-name-and-town?street_name=Bramwell+Way&town=London'

# %%
html_text = requests.get(final_epc_url).text
soup = BeautifulSoup(html_text, 'lxml')

# %%
# To display full output in Notebook, instead of only the last result 
from IPython.core.interactiveshell import InteractiveShell 

InteractiveShell.ast_node_interactivity = "all"

# %%
from statistics import mode


#for some reason it isn't 
epc_ads=soup.find_all('tr', class_ = 'govuk-table__row')
epc_ads[1]
# epc_ads

# results_epc = {}
epc_id_ad = 0
flat_address_final=[]
epc_rating=[]
for k in range(len(epc_ads)):
    ad = epc_ads[k]
#     results_epc[epc_id_ad] = {}
    

    
    flat_address = ad.find_all('a', class_='govuk-link')
#     flat_address = ad.find_all('a', href=True)
    
#     flat_address_final.append(flat_address[0].get_text(strip=True))
    if len(flat_address) !=0:
        flat_address_final.append(flat_address[0].get_text(strip=True))
    else: 
        continue
    
    epc_rating.append(ad.find_all('td', class_='govuk-table__cell')[0].get_text(strip=True))
       
    epc_id_ad += 1
#     flat_address = ad.find('a', class_='govuk-link')#.get_text()
#     flat_address = ad.get_text(strip=True)

epc_rating
len(flat_address_final)
len(epc_rating)
mode(epc_rating)
    
#     epc_rating=ad.find(class_='govuk-table__cell')
# flat_address
# Out:
# <tr class="govuk-table__row">
# <th class="govuk-table__header" scope="row">
# <a class="govuk-link" href="/energy-certificate/2338-5927-7320-3255-1910">
#               Flat 3 Kingfisher Heights, 2, Bramwell Way, LONDON, E16 2GQ
#             </a>
# </th>
# <td class="govuk-table__cell">B</td>
# <td class="govuk-table__cell">
# <span style="white-space: nowrap;">
#               26 October 2025
#             </span>
# </td>
# </tr>
# ['B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'C',
#  'C',
#  'B',
#  'C']
# 194
# 194
# 'B'

# %%
#get the results of EPC ratings for all the street names in the Dexter scraper:

#first create a list of URLs for scraping
list_epc_urls=[]
epc_url='https://find-energy-certificate.digital.communities.gov.uk/find-a-certificate/search-by-street-name-and-town?street_name='
town_url='&town=London'
epc_avg=[]

for street_name in list(cleaned['street_name']):
    url_street_name=street_name.replace(' ','+')
    list_epc_urls.append(epc_url+url_street_name+town_url)

    #iterate through
for url in list_epc_urls:
    
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'lxml')
    epc_ads=soup.find_all('tr', class_ = 'govuk-table__row')
    
    epc_id_ad = 0
    flat_address_final=[]
    epc_rating=[]
    for k in range(len(epc_ads)):
        ad = epc_ads[k]
        flat_address = ad.find_all('a', class_='govuk-link')
  
        if len(flat_address) !=0:
            flat_address_final.append(flat_address[0].get_text(strip=True))
        else: 
            continue

        epc_rating.append(ad.find_all('td', class_='govuk-table__cell')[0].get_text(strip=True))

        epc_id_ad += 1
    epc_avg.append(mode(epc_rating))
avg_epc_tuple=list(zip(list(cleaned['street_name']),epc_avg))
street_name_epc=pd.DataFrame(avg_epc_tuple, columns=['street_name','average_epc'])
street_name_epc
# Out:
#           street_name average_epc
# 0      Lancaster Gate           C
# 1     Wilton Crescent           D
# 2     Whitehall Place           D
# 3    Old Queen Street           C
# 4     Whitehall Place           D
# 5     Whitehall Place           D
# 6      Radnor Terrace           B
# 7        Queen Street           C
# 8        Queen Street           C
# 9           Hall Road           D
# 10      Ladbroke Road           D
# 11  Fairhazel Gardens           D
# 12         Kings Road           D
# 13  Philbeach Gardens           C
# 14       Green Street           D

# %%
#trying to get the full list of London streets 
#link: http://london.streetmapof.co.uk/


london_streetmap='http://london.streetmapof.co.uk/'
alphabet_letter='a'
streetmap_url=london_streetmap+alphabet_letter+'/'

    
map_html_text = requests.get(streetmap_url).text
soup_map = BeautifulSoup(map_html_text, 'lxml')

#find street names in the map:
map_ads=soup_map.find_all('td', { "valign": "top" })


# ad = map_ads[1]
count_pages=[]
[count_pages.append(a) for a in soup_map.find_all('a', href=True) if a['href'].startswith(f'/{alphabet_letter}/')]
len(count_pages) 
count_pages
# Out:
# [None, None, None, None, None, None]
# 6
# [<a href="/a/" style="color:#000">[ 1 ]</a>,
#  <a href="/a/2" style="color:#AAA">[ 2 ]</a>,
#  <a href="/a/3" style="color:#AAA">[ 3 ]</a>,
#  <a href="/a/4" style="color:#AAA">[ 4 ]</a>,
#  <a href="/a/5" style="color:#AAA">[ 5 ]</a>,
#  <a href="/a/6" style="color:#AAA">[ 6 ]</a>]

# %%
#FINAL for the bigger for loop to collect all the elements of the list for letter "A"
list_starting_withA=[]
for i in range(len(count_pages)):
    if i==0:
        streetmap_url=london_streetmap+alphabet_letter+'/'
        print("page",i," ",streetmap_url)
        map_html_text = requests.get(streetmap_url).text
        soup_map = BeautifulSoup(map_html_text, 'lxml')
        map_ads=soup_map.find_all('td', { "valign": "top" })
        for k in range(len(map_ads)):
            ad = map_ads[k]


            for a in ad.find_all('a', href=True):
                if a['href'].startswith(f'/{alphabet_letter}/'):
                    count_pages.append(a)
                else:
                    list_starting_withA.append(a.get_text(strip=True))
    else:
        streetmap_url=london_streetmap+alphabet_letter+'/'+str(i+1)
        print("page",i," ",streetmap_url)
        map_html_text = requests.get(streetmap_url).text
        soup_map = BeautifulSoup(map_html_text, 'lxml')
        map_ads=soup_map.find_all('td', { "valign": "top" })

        for k in range(len(map_ads)):
            ad = map_ads[k]


            for a in ad.find_all('a', href=True):
                if a['href'].startswith(f'/{alphabet_letter}/'):
                    count_pages.append(a)
                else:
                    list_starting_withA.append(a.get_text(strip=True))
list_starting_withA
len(set(list_starting_withA))
# Out:
# page 0   http://london.streetmapof.co.uk/a/
# page 1   http://london.streetmapof.co.uk/a/2
# page 2   http://london.streetmapof.co.uk/a/3
# page 3   http://london.streetmapof.co.uk/a/4
# page 4   http://london.streetmapof.co.uk/a/5
# page 5   http://london.streetmapof.co.uk/a/6
# ['Aaron Hill Road',
#  'Abberley Mews',
#  'Abbess Close',
#  'Abbeville Road',
#  'Abbey Drive',
#  'Abbey Gardens',
#  'Abbey Grove',
#  'Abbey Lane',
#  'Abbey Mews',
#  'Abbey Orchard Street',
#  'Abbey Parade',
#  'Abbey Road',
#  'Abbey Street',
#  'Abbey Terrace',
#  'Abbey View',
#  'Abbey Wood Road',
#  'Abbeyfield Estate',
#  'Abbeyfield Road',
#  'Abbeyfields Close',
#  'Abbots Gardens',
#  'Abbots Manor',
#  'Abbots Park',
#  'Abbots Place',
#  'Abbots Road',
#  'Abbots Terrace',
#  'Abbots Walk',
#  'Abbotsbury Close',
#  'Abbotsbury Mews',
#  'Abbotsbury Road',
#  'Abbotsford Avenue',
#  'Abbotshade Road',
#  'Abbotshall Avenue',
#  'Abbotshall Road',
#  'Abbotsleigh Road',
#  'Abbotstone Road',
#  'Abbotswell Road',
#  'Abbotswood Road',
#  'Abbott Avenue',
#  'Abbott Road',
#  'Abbotts Close',
#  'Abbotts Crescent',
#  'Abbotts Park Road',
#  'Abchurch Lane',
#  'Abdale Road',
#  'Aberavon Road',
#  'Abercairn Road',
#  'Abercorn Close',
#  'Abercorn Place',
#  'Abercorn Road',
#  'Abercorn Way',
#  'Abercrombie Street',
#  'Aberdare Gardens',
#  'Aberdeen Lane',
#  'Aberdeen Parade',
#  'Aberdeen Park',
#  'Aberdeen Place',
#  'Aberdeen Road',
#  'Aberdeen Terrace',
#  'Aberdour Street',
#  'Aberfeldy Street',
#  'Aberford Gardens',
#  'Aberfoyle Road',
#  'Abergeldie Road',
#  'Abernethy Road',
#  'Abersham Road',
#  'Abery Street',
#  'Abingdon Close',
#  'Abingdon Road',
#  'Abingdon Villas',
#  'Abinger Grove',
#  'Abinger Mews',
#  'Abinger Road',
#  'Ablett Street',
#  'Abney Gardens',
#  'Abney Park Terrace',
#  'Aboyne Drive',
#  'Aboyne Road',
#  'Abyssinia Close',
#  'Abyssinia Road',
#  'Acacia Avenue',
#  'Acacia Close',
#  'Acacia Gardens',
#  'Acacia Grove',
#  'Acacia Place',
#  'Acacia Road',
#  'Academy Buildings',
#  'Academy Place',
#  'Acanthus Drive',
#  'Acanthus Road',
#  'Accommodation Road',
#  'Acfold Road',
#  'Achilles Close',
#  'Achilles Road',
#  'Achilles Street',
#  'Acklam Road',
#  'Acklington Drive',
#  'Ackmar Road',
#  'Ackroyd Drive',
#  'Ackroyd Road',
#  'Acland Close',
#  'Acland Crescent',
#  'Acland Road',
#  'Acol Road',
#  'Acorn Close',
#  'Acorn Gardens',
#  'Acorn Parade',
#  'Acorn Walk',
#  'Acorn Way',
#  'Acre Drive',
#  'Acre Lane',
#  'Acre Road',
#  'Acris Street',
#  'Acton Close',
#  'Acton Lane',
#  'Acton Street',
#  'Acuba Road',
#  'Acworth Close',
#  'Ada Gardens',
#  'Ada Place',
#  'Ada Road',
#  'Ada Street',
#  'Adair Close',
#  'Adair Road',
#  'Adam & Eve Mews',
#  'Adam Close',
#  'Adam Road',
#  'Adam Street',
#  'Adam Walk',
#  'Adams Close',
#  'Adams Gardens Estate',
#  'Adams Place',
#  'Adams Road',
#  'Adams Row',
#  'Adamson Road',
#  'Adamsrill Road',
#  'Adare Walk',
#  'Adderley Gardens',
#  'Adderley Grove',
#  'Adderley Street',
#  'Addington Drive',
#  'Addington Grove',
#  'Addington Road',
#  'Addington Square',
#  'Addison Avenue',
#  'Addison Bridge Place',
#  'Addison Crescent',
#  'Addison Drive',
#  'Addison Gardens',
#  'Addison Grove',
#  'Addison Place',
#  'Addison Road',
#  'Addison Terrace',
#  'Addison Way',
#  'Addle Hill',
#  'Addle Street',
#  'Adelaide Avenue',
#  'Adelaide Grove',
#  'Adelaide Road',
#  'Adelaide Street',
#  'Adelaide Walk',
#  'Adelina Grove',
#  'Adelina Mews',
#  'Adeline Place',
#  'Aden Grove',
#  'Aden Terrace',
#  'Adeney Close',
#  'Adenmore Road',
#  'Adie Road',
#  'Adine Road',
#  'Adler Street',
#  'Adley Street',
#  'Adlington Close',
#  'Admaston Road',
#  'Admiral Place',
#  'Admiral Seymour Road',
#  'Admiral Square',
#  'Admiral Street',
#  'Admiral Walk',
#  'Admirals Close',
#  'Admirals Gate',
#  'Admirals Walk',
#  'Admirals Way',
#  'Admiralty Close',
#  'Adolf Street',
#  'Adolphus Road',
#  'Adolphus Street',
#  'Adpar Street',
#  'Adrian Avenue',
#  'Adrian Mews',
#  'Advance Road',
#  'Adys Lawn',
#  'Adys Road',
#  'Aeroville',
#  'Afghan Road',
#  'Aftab Terrace',
#  'Agamemnon Road',
#  'Agar Grove',
#  'Agar Place',
#  'Agar Street',
#  'Agate Close',
#  'Aaron Hill Road',
#  'Abberley Mews',
#  'Abbess Close',
#  'Abbeville Road',
#  'Abbey Drive',
#  'Abbey Gardens',
#  'Abbey Grove',
#  'Abbey Lane',
#  'Abbey Mews',
#  'Abbey Orchard Street',
#  'Abbey Parade',
#  'Abbey Road',
#  'Abbey Street',
#  'Abbey Terrace',
#  'Abbey View',
#  'Abbey Wood Road',
#  'Abbeyfield Estate',
#  'Abbeyfield Road',
#  'Abbeyfields Close',
#  'Abbots Gardens',
#  'Abbots Manor',
#  'Abbots Park',
#  'Abbots Place',
#  'Abbots Road',
#  'Abbots Terrace',
#  'Abbots Walk',
#  'Abbotsbury Close',
#  'Abbotsbury Mews',
#  'Abbotsbury Road',
#  'Abbotsford Avenue',
#  'Abbotshade Road',
#  'Abbotshall Avenue',
#  'Abbotshall Road',
#  'Abbotsleigh Road',
#  'Abbotstone Road',
#  'Abbotswell Road',
#  'Abbotswood Road',
#  'Abbott Avenue',
#  'Abbott Road',
#  'Abbotts Close',
#  'Abbotts Crescent',
#  'Abbotts Park Road',
#  'Abchurch Lane',
#  'Abdale Road',
#  'Aberavon Road',
#  'Abercairn Road',
#  'Abercorn Close',
#  'Abercorn Place',
#  'Abercorn Road',
#  'Abercorn Way',
#  'Abercrombie Street',
#  'Aberdare Gardens',
#  'Aberdeen Lane',
#  'Aberdeen Parade',
#  'Aberdeen Park',
#  'Aberdeen Place',
#  'Aberdeen Road',
#  'Aberdeen Terrace',
#  'Aberdour Street',
#  'Aberfeldy Street',
#  'Aberford Gardens',
#  'Aberfoyle Road',
#  'Abergeldie Road',
#  'Abernethy Road',
#  'Abersham Road',
#  'Abery Street',
#  'Abingdon Close',
#  'Abingdon Road',
#  'Abingdon Villas',
#  'Abinger Grove',
#  'Abinger Mews',
#  'Abinger Road',
#  'Ablett Street',
#  'Abney Gardens',
#  'Abney Park Terrace',
#  'Aboyne Drive',
#  'Aboyne Road',
#  'Abyssinia Close',
#  'Abyssinia Road',
#  'Acacia Avenue',
#  'Acacia Close',
#  'Acacia Gardens',
#  'Acacia Grove',
#  'Acacia Place',
#  'Acacia Road',
#  'Academy Buildings',
#  'Academy Place',
#  'Acanthus Drive',
#  'Acanthus Road',
#  'Accommodation Road',
#  'Acfold Road',
#  'Achilles Close',
#  'Achilles Road',
#  'Achilles Street',
#  'Acklam Road',
#  'Acklington Drive',
#  'Ackmar Road',
#  'Ackroyd Drive',
#  'Ackroyd Road',
#  'Acland Close',
#  'Acland Crescent',
#  'Acland Road',
#  'Acol Road',
#  'Acorn Close',
#  'Acorn Gardens',
#  'Acorn Parade',
#  'Acorn Walk',
#  'Acorn Way',
#  'Acre Drive',
#  'Acre Lane',
#  'Acre Road',
#  'Acris Street',
#  'Acton Close',
#  'Acton Lane',
#  'Acton Street',
#  'Acuba Road',
#  'Acworth Close',
#  'Ada Gardens',
#  'Ada Place',
#  'Ada Road',
#  'Ada Street',
#  'Adair Close',
#  'Adair Road',
#  'Adam & Eve Mews',
#  'Adam Close',
#  'Adam Road',
#  'Adam Street',
#  'Adam Walk',
#  'Adams Close',
#  'Adams Gardens Estate',
#  'Adams Place',
#  'Adams Road',
#  'Adams Row',
#  'Adamson Road',
#  'Adamsrill Road',
#  'Adare Walk',
#  'Adderley Gardens',
#  'Adderley Grove',
#  'Adderley Street',
#  'Addington Drive',
#  'Addington Grove',
#  'Addington Road',
#  'Addington Square',
#  'Addison Avenue',
#  'Addison Bridge Place',
#  'Addison Crescent',
#  'Addison Drive',
#  'Addison Gardens',
#  'Addison Grove',
#  'Addison Place',
#  'Addison Road',
#  'Addison Terrace',
#  'Addison Way',
#  'Addle Hill',
#  'Addle Street',
#  'Adelaide Avenue',
#  'Adelaide Grove',
#  'Adelaide Road',
#  'Adelaide Street',
#  'Adelaide Walk',
#  'Adelina Grove',
#  'Adelina Mews',
#  'Adeline Place',
#  'Aden Grove',
#  'Aden Terrace',
#  'Adeney Close',
#  'Adenmore Road',
#  'Adie Road',
#  'Adine Road',
#  'Adler Street',
#  'Adley Street',
#  'Adlington Close',
#  'Admaston Road',
#  'Admiral Place',
#  'Admiral Seymour Road',
#  'Admiral Square',
#  'Admiral Street',
#  'Admiral Walk',
#  'Admirals Close',
#  'Admirals Gate',
#  'Admirals Walk',
#  'Admirals Way',
#  'Admiralty Close',
#  'Adolf Street',
#  'Adolphus Road',
#  'Adolphus Street',
#  'Adpar Street',
#  'Adrian Avenue',
#  'Adrian Mews',
#  'Advance Road',
#  'Adys Lawn',
#  'Adys Road',
#  'Aeroville',
#  'Afghan Road',
#  'Aftab Terrace',
#  'Agamemnon Road',
#  'Agar Grove',
#  'Agar Place',
#  'Agar Street',
#  'Agate Close',
#  'Agate Road',
#  'Agatha Close',
#  'Agaton Road',
#  'Agdon Street',
#  'Agincourt Road',
#  'Agnes Close',
#  'Agnes Riley Gardens',
#  'Agnes Road',
#  'Agnes Street',
#  'Agnesfield Close',
#  'Agnew Road',
#  'Aileen Walk',
#  'Ailsa Street',
#  'Ainger Mews',
#  'Ainger Road',
#  'Ainsdale Drive',
#  'Ainsdale Road',
#  'Ainsley Close',
#  'Ainsley Street',
#  'Ainslie Walk',
#  'Ainslie Wood Crescent',
#  'Ainslie Wood Gardens',
#  'Ainslie Wood Road',
#  'Ainsty Estate',
#  'Ainsworth Close',
#  'Ainsworth Road',
#  'Ainsworth Way',
#  'Aintree Avenue',
#  'Aintree Estate',
#  'Air Street',
#  'Airdrie Close',
#  'Airedale Avenue',
#  'Airedale Avenue South',
#  'Airedale Road',
#  'Airlie Gardens',
#  'Aisgill Avenue',
#  'Aisher Road',
#  'Aislibie Road',
#  'Aiten Place',
#  'Aitken Close',
#  'Aitken Road',
#  'Ajax Avenue',
#  'Ajax Road',
#  'Akehurst Street',
#  'Akenside Road',
#  'Akerman Road',
#  'Alabama Street',
#  'Alacross Road',
#  'Alan Hocken Way',
#  'Alan Road',
#  'Alander Mews',
#  'Alanthus Close',
#  'Alba Gardens',
#  'Alba Place',
#  'Albacore Crescent',
#  'Alban Highwalk',
#  'Albany',
#  'Albany Close',
#  'Albany Cottages',
#  'Albany Courtyard',
#  'Albany Mews',
#  'Albany Road',
#  'Albany Row',
#  'Albany Street',
#  'Albany Terrace',
#  'Albatross Street',
#  'Albemarle Street',
#  'Albemarle Way',
#  'Alberon Gardens',
#  'Albert Avenue',
#  'Albert Bridge Road',
#  'Albert Carr Gardens',
#  'Albert Close',
#  'Albert Cottages',
#  'Albert Crescent',
#  'Albert Drive',
#  'Albert Embankment',
#  'Albert Gardens',
#  'Albert Gate',
#  'Albert Grove',
#  'Albert Mews',
#  'Albert Place',
#  'Albert Road',
#  'Albert Square',
#  'Albert Street',
#  'Albert Terrace',
#  'Albert Terrace Mews',
#  'Albert Walk',
#  'Albert Way',
#  'Alberta Estate',
#  'Alberta Street',
#  'Albion Avenue',
#  'Albion Close',
#  'Albion Drive',
#  'Albion Estate',
#  'Albion Grove',
#  'Albion Mews',
#  'Albion Parade',
#  'Albion Place',
#  'Albion Road',
#  'Albion Square',
#  'Albion Street',
#  'Albion Terrace',
#  'Albion Villas Road',
#  'Albion Way',
#  'Albion Yard',
#  'Albury Mews',
#  'Albury Street',
#  'Albyn Road',
#  'Alcester Crescent',
#  'Alconbury Road',
#  'Alcott Close',
#  'Aldbourne Road',
#  'Aldbridge Street',
#  'Aldburgh Mews',
#  'Aldbury Mews',
#  'Aldebert Terrace',
#  'Aldeburgh Close',
#  'Aldeburgh Street',
#  'Alden Avenue',
#  'Aldenham Street',
#  'Aldensley Road',
#  'Alder Close',
#  'Alder Grove',
#  'Alder Mews',
#  'Alder Road',
#  'Alderbrook Road',
#  'Alderbury Road',
#  'Alderholt Way',
#  'Aldermans Hill',
#  'Aldermoor Road',
#  'Alderney Road',
#  'Alderney Street',
#  'Alders Close',
#  'Aldersbrook Lane',
#  'Aldersbrook Road',
#  'Aldersgate Street',
#  'Aldersgrove Avenue',
#  'Aldershot Road',
#  'Aldershot Terrace',
#  'Alderton Close',
#  'Alderton Crescent',
#  'Alderton Road',
#  'Alderton Way',
#  'Alderville Road',
#  'Alderwood Road',
#  'Aldford Street',
#  'Aldgate Barrs',
#  'Aldgate High Street',
#  'Aldine Street',
#  'Aldis Mews',
#  'Aldis Street',
#  'Aldred Road',
#  'Aldren Road',
#  'Aldrich Terrace',
#  'Aldriche Way',
#  'Aldridge Road Villas',
#  'Aldridge Walk',
#  'Aldrington Road',
#  'Aldsworth Close',
#  'Aldwick Close',
#  'Aldworth Grove',
#  'Aldworth Road',
#  'Aldwych',
#  'Alesia Close',
#  'Alestan Beck Road',
#  'Alexander Avenue',
#  'Alexander Evans Mews',
#  'Alexander Mews',
#  'Alexander Place',
#  'Alexander Road',
#  'Alexander Square',
#  'Alexander Street',
#  'Alexander Terrace',
#  'Alexandra Avenue',
#  'Alexandra Close',
#  'Alexandra Drive',
#  'Alexandra Gardens',
#  'Alexandra Grove',
#  'Alexandra Mews',
#  'Alexandra Park Road',
#  'Alexandra Place',
#  'Alexandra Road',
#  'Alexandra Street',
#  'Alexandra Walk',
#  'Alexandria Road',
#  'Alexis Street',
#  'Alfearn Road',
#  'Alfoxton Avenue',
#  'Alfred Close',
#  'Alfred Place',
#  'Alfred Road',
#  'Alfred Street',
#  'Alfred Villas',
#  'Alfreda Street',
#  'Alfreton Close',
#  'Alfriston Road',
#  'Algarve Road',
#  'Algernon Road',
#  'Algiers Road',
#  'Agate Road',
#  'Agatha Close',
#  'Agaton Road',
#  'Agdon Street',
#  'Agincourt Road',
#  'Agnes Close',
#  'Agnes Riley Gardens',
#  'Agnes Road',
#  'Agnes Street',
#  'Agnesfield Close',
#  'Agnew Road',
#  'Aileen Walk',
#  'Ailsa Street',
#  'Ainger Mews',
#  'Ainger Road',
#  'Ainsdale Drive',
#  'Ainsdale Road',
#  'Ainsley Close',
#  'Ainsley Street',
#  'Ainslie Walk',
#  'Ainslie Wood Crescent',
#  'Ainslie Wood Gardens',
#  'Ainslie Wood Road',
#  'Ainsty Estate',
#  'Ainsworth Close',
#  'Ainsworth Road',
#  'Ainsworth Way',
#  'Aintree Avenue',
#  'Aintree Estate',
#  'Air Street',
#  'Airdrie Close',
#  'Airedale Avenue',
#  'Airedale Avenue South',
#  'Airedale Road',
#  'Airlie Gardens',
#  'Aisgill Avenue',
#  'Aisher Road',
#  'Aislibie Road',
#  'Aiten Place',
#  'Aitken Close',
#  'Aitken Road',
#  'Ajax Avenue',
#  'Ajax Road',
#  'Akehurst Street',
#  'Akenside Road',
#  'Akerman Road',
#  'Alabama Street',
#  'Alacross Road',
#  'Alan Hocken Way',
#  'Alan Road',
#  'Alander Mews',
#  'Alanthus Close',
#  'Alba Gardens',
#  'Alba Place',
#  'Albacore Crescent',
#  'Alban Highwalk',
#  'Albany',
#  'Albany Close',
#  'Albany Cottages',
#  'Albany Courtyard',
#  'Albany Mews',
#  'Albany Road',
#  'Albany Row',
#  'Albany Street',
#  'Albany Terrace',
#  'Albatross Street',
#  'Albemarle Street',
#  'Albemarle Way',
#  'Alberon Gardens',
#  'Albert Avenue',
#  'Albert Bridge Road',
#  'Albert Carr Gardens',
#  'Albert Close',
#  'Albert Cottages',
#  'Albert Crescent',
#  'Albert Drive',
#  'Albert Embankment',
#  'Albert Gardens',
#  'Albert Gate',
#  'Albert Grove',
#  'Albert Mews',
#  'Albert Place',
#  'Albert Road',
#  'Albert Square',
#  'Albert Street',
#  'Albert Terrace',
#  'Albert Terrace Mews',
#  'Albert Walk',
#  'Albert Way',
#  'Alberta Estate',
#  'Alberta Street',
#  'Albion Avenue',
#  'Albion Close',
#  'Albion Drive',
#  'Albion Estate',
#  'Albion Grove',
#  'Albion Mews',
#  'Albion Parade',
#  'Albion Place',
#  'Albion Road',
#  'Albion Square',
#  'Albion Street',
#  'Albion Terrace',
#  'Albion Villas Road',
#  'Albion Way',
#  'Albion Yard',
#  'Albury Mews',
#  'Albury Street',
#  'Albyn Road',
#  'Alcester Crescent',
#  'Alconbury Road',
#  'Alcott Close',
#  'Aldbourne Road',
#  'Aldbridge Street',
#  'Aldburgh Mews',
#  'Aldbury Mews',
#  'Aldebert Terrace',
#  'Aldeburgh Close',
#  'Aldeburgh Street',
#  'Alden Avenue',
#  'Aldenham Street',
#  'Aldensley Road',
#  'Alder Close',
#  'Alder Grove',
#  'Alder Mews',
#  'Alder Road',
#  'Alderbrook Road',
#  'Alderbury Road',
#  'Alderholt Way',
#  'Aldermans Hill',
#  'Aldermoor Road',
#  'Alderney Road',
#  'Alderney Street',
#  'Alders Close',
#  'Aldersbrook Lane',
#  'Aldersbrook Road',
#  'Aldersgate Street',
#  'Aldersgrove Avenue',
#  'Aldershot Road',
#  'Aldershot Terrace',
#  'Alderton Close',
#  'Alderton Crescent',
#  'Alderton Road',
#  'Alderton Way',
#  'Alderville Road',
#  'Alderwood Road',
#  'Aldford Street',
#  'Aldgate Barrs',
#  'Aldgate High Street',
#  'Aldine Street',
#  'Aldis Mews',
#  'Aldis Street',
#  'Aldred Road',
#  'Aldren Road',
#  'Aldrich Terrace',
#  'Aldriche Way',
#  'Aldridge Road Villas',
#  'Aldridge Walk',
#  'Aldrington Road',
#  'Aldsworth Close',
#  'Aldwick Close',
#  'Aldworth Grove',
#  'Aldworth Road',
#  'Aldwych',
#  'Alesia Close',
#  'Alestan Beck Road',
#  'Alexander Avenue',
#  'Alexander Evans Mews',
#  'Alexander Mews',
#  'Alexander Place',
#  'Alexander Road',
#  'Alexander Square',
#  'Alexander Street',
#  'Alexander Terrace',
#  'Alexandra Avenue',
#  'Alexandra Close',
#  'Alexandra Drive',
#  'Alexandra Gardens',
#  'Alexandra Grove',
#  'Alexandra Mews',
#  'Alexandra Park Road',
#  'Alexandra Place',
#  'Alexandra Road',
#  'Alexandra Street',
#  'Alexandra Walk',
#  'Alexandria Road',
#  'Alexis Street',
#  'Alfearn Road',
#  'Alfoxton Avenue',
#  'Alfred Close',
#  'Alfred Place',
#  'Alfred Road',
#  'Alfred Street',
#  'Alfred Villas',
#  'Alfreda Street',
#  'Alfreton Close',
#  'Alfriston Road',
#  'Algarve Road',
#  'Algernon Road',
#  'Algiers Road',
#  'Alice Lane',
#  'Alice Street',
#  'Alice Thompson Close',
#  'Alice Walker Close',
#  'Alie Street',
#  'Alington Crescent',
#  'Alison Close',
#  'Aliwal Road',
#  'Alkerden Road',
#  'Alkham Road',
#  'All Hallows Road',
#  'All Saints Close',
#  'All Saints Road',
#  'All Saints Street',
#  'All Souls Avenue',
#  'All Souls Place',
#  'Allan Barclay Close',
#  'Allan Way',
#  'Allandale Avenue',
#  'Allanson Court',
#  'Allard Gardens',
#  'Allardyce Street',
#  'Allcroft Road',
#  'Allen Edwards Drive',
#  'Allen Road',
#  'Allen Street',
#  'Allenby Road',
#  'Allendale Close',
#  'Allensbury Place',
#  'Allenswood Road',
#  'Allerford Road',
#  'Allerton Road',
#  'Allerton Walk',
#  'Allestree Road',
#  'Alleyn Crescent',
#  'Alleyn Park',
#  'Alleyn Road',
#  'Allfarthing Lane',
#  'Allhallows Road',
#  'Alliance Road',
#  'Allingham Close',
#  'Allingham Mews',
#  'Allingham Street',
#  'Allington Avenue',
#  'Allington Road',
#  'Allington Street',
#  'Allison Close',
#  'Allison Grove',
#  'Allison Road',
#  'Allitsen Road',
#  'Allnutt Way',
#  'Alloa Road',
#  'Alloway Road',
#  'Allsop Place',
#  'Allum Way',
#  'Allwood Close',
#  'Alma Avenue',
#  'Alma Close',
#  'Alma Grove',
#  'Alma Place',
#  'Alma Road',
#  'Alma Square',
#  'Alma Street',
#  'Alma Terrace',
#  'Almack Road',
#  'Almeida Street',
#  'Almer Road',
#  'Almeric Road',
#  'Almington Street',
#  'Almond Avenue',
#  'Almond Close',
#  'Almond Road',
#  'Almorah Road',
#  'Alnwick Road',
#  'Alperton Street',
#  'Alpha Grove',
#  'Alpha Place',
#  'Alpha Road',
#  'Alpha Street',
#  'Alphabet Square',
#  'Alphea Close',
#  'Alpine Grove',
#  'Alpine Road',
#  'Alpine Way',
#  'Alric Avenue',
#  'Alroy Road',
#  'Alscot Road',
#  'Alscot Way',
#  'Alston Road',
#  'Alt Grove',
#  'Altair Close',
#  'Altash Way',
#  'Altenburg Avenue',
#  'Altenburg Gardens',
#  'Althea Street',
#  'Althorne Gardens',
#  'Althorp Road',
#  'Althorpe Mews',
#  'Altmore Avenue',
#  'Alton Road',
#  'Alton Street',
#  'Alvanley Gardens',
#  'Alverston Gardens',
#  'Alverstone Avenue',
#  'Alverstone Gardens',
#  'Alverstone Road',
#  'Alverton Street',
#  'Alvey Street',
#  'Alvington Crescent',
#  'Alwold Crescent',
#  'Alwyn Avenue',
#  'Alwyn Gardens',
#  'Alwyne Place',
#  'Alwyne Road',
#  'Alwyne Square',
#  'Alwyne Villas',
#  'Alyn Bank',
#  'Alyth Gardens',
#  'Ambassador Gardens',
#  'Ambassador Square',
#  'Amber Avenue',
#  'Amber Court',
#  'Amber Grove',
#  'Amberden Avenue',
#  'Ambergate Street',
#  'Amberley Grove',
#  'Amberley Road',
#  'Amblecote Close',
#  'Amblecote Meadows',
#  'Amblecote Road',
#  'Ambler Road',
#  'Ambleside Avenue',
#  'Ambleside Close',
#  'Ambleside Gardens',
#  'Ambleside Road',
#  'Ambrosden Avenue',
#  'Ambrose Avenue',
#  'Ambrose Close',
#  'Ambrose Mews',
#  'Ambrose Street',
#  'Ambrose Walk',
#  'Amelia Street',
#  'Amen Corner',
#  'Amen Court',
#  'Amerland Road',
#  'Amersham Avenue',
#  'Amersham Grove',
#  'Amersham Road',
#  'Amersham Vale',
#  'Amery Gardens',
#  'Ames Cottages',
#  'Amesbury Avenue',
#  'Amesbury Drive',
#  'Amethyst Road',
#  'Amherst Avenue',
#  'Amherst Gardens',
#  'Amherst Road',
#  'Amhurst Parade',
#  'Amhurst Park',
#  'Amhurst Road',
#  'Amhurst Walk',
#  'Amiel Street',
#  'Amies Street',
#  'Amina Way',
#  'Amity Grove',
#  'Amity Road',
#  'Ammanford Green',
#  'Amner Road',
#  'Amor Road',
#  'Amott Road',
#  'Ampleforth Road',
#  'Ampthill Square',
#  'Ampton Place',
#  'Ampton Street',
#  'Amroth Close',
#  'Amroth Green',
#  'Amsterdam Road',
#  'Amwell Street',
#  'Amy Warne Close',
#  'Amyruth Road',
#  'Anatola Road',
#  'Ancaster Street',
#  'Anchor & Hope Lane',
#  'Anchor Mews',
#  'Anchor Street',
#  'Anchor Yard',
#  'Anchorage Close',
#  'Ancill Close',
#  'Ancona Road',
#  'Andalus Road',
#  'Anderson Close',
#  'Anderson Road',
#  'Anderson Square',
#  'Anderson Street',
#  'Anderton Close',
#  'Andover Avenue',
#  'Andover Place',
#  'Andover Road',
#  'Andre Street',
#  'Andrew Place',
#  ...]
# 1159

# %%
list_starting_withA
len(set(list_starting_withA))
# Out:
# ['Aaron Hill Road',
#  'Abberley Mews',
#  'Abbess Close',
#  'Abbeville Road',
#  'Abbey Drive',
#  'Abbey Gardens',
#  'Abbey Grove',
#  'Abbey Lane',
#  'Abbey Mews',
#  'Abbey Orchard Street',
#  'Abbey Parade',
#  'Abbey Road',
#  'Abbey Street',
#  'Abbey Terrace',
#  'Abbey View',
#  'Abbey Wood Road',
#  'Abbeyfield Estate',
#  'Abbeyfield Road',
#  'Abbeyfields Close',
#  'Abbots Gardens',
#  'Abbots Manor',
#  'Abbots Park',
#  'Abbots Place',
#  'Abbots Road',
#  'Abbots Terrace',
#  'Abbots Walk',
#  'Abbotsbury Close',
#  'Abbotsbury Mews',
#  'Abbotsbury Road',
#  'Abbotsford Avenue',
#  'Abbotshade Road',
#  'Abbotshall Avenue',
#  'Abbotshall Road',
#  'Abbotsleigh Road',
#  'Abbotstone Road',
#  'Abbotswell Road',
#  'Abbotswood Road',
#  'Abbott Avenue',
#  'Abbott Road',
#  'Abbotts Close',
#  'Abbotts Crescent',
#  'Abbotts Park Road',
#  'Abchurch Lane',
#  'Abdale Road',
#  'Aberavon Road',
#  'Abercairn Road',
#  'Abercorn Close',
#  'Abercorn Place',
#  'Abercorn Road',
#  'Abercorn Way',
#  'Abercrombie Street',
#  'Aberdare Gardens',
#  'Aberdeen Lane',
#  'Aberdeen Parade',
#  'Aberdeen Park',
#  'Aberdeen Place',
#  'Aberdeen Road',
#  'Aberdeen Terrace',
#  'Aberdour Street',
#  'Aberfeldy Street',
#  'Aberford Gardens',
#  'Aberfoyle Road',
#  'Abergeldie Road',
#  'Abernethy Road',
#  'Abersham Road',
#  'Abery Street',
#  'Abingdon Close',
#  'Abingdon Road',
#  'Abingdon Villas',
#  'Abinger Grove',
#  'Abinger Mews',
#  'Abinger Road',
#  'Ablett Street',
#  'Abney Gardens',
#  'Abney Park Terrace',
#  'Aboyne Drive',
#  'Aboyne Road',
#  'Abyssinia Close',
#  'Abyssinia Road',
#  'Acacia Avenue',
#  'Acacia Close',
#  'Acacia Gardens',
#  'Acacia Grove',
#  'Acacia Place',
#  'Acacia Road',
#  'Academy Buildings',
#  'Academy Place',
#  'Acanthus Drive',
#  'Acanthus Road',
#  'Accommodation Road',
#  'Acfold Road',
#  'Achilles Close',
#  'Achilles Road',
#  'Achilles Street',
#  'Acklam Road',
#  'Acklington Drive',
#  'Ackmar Road',
#  'Ackroyd Drive',
#  'Ackroyd Road',
#  'Acland Close',
#  'Acland Crescent',
#  'Acland Road',
#  'Acol Road',
#  'Acorn Close',
#  'Acorn Gardens',
#  'Acorn Parade',
#  'Acorn Walk',
#  'Acorn Way',
#  'Acre Drive',
#  'Acre Lane',
#  'Acre Road',
#  'Acris Street',
#  'Acton Close',
#  'Acton Lane',
#  'Acton Street',
#  'Acuba Road',
#  'Acworth Close',
#  'Ada Gardens',
#  'Ada Place',
#  'Ada Road',
#  'Ada Street',
#  'Adair Close',
#  'Adair Road',
#  'Adam & Eve Mews',
#  'Adam Close',
#  'Adam Road',
#  'Adam Street',
#  'Adam Walk',
#  'Adams Close',
#  'Adams Gardens Estate',
#  'Adams Place',
#  'Adams Road',
#  'Adams Row',
#  'Adamson Road',
#  'Adamsrill Road',
#  'Adare Walk',
#  'Adderley Gardens',
#  'Adderley Grove',
#  'Adderley Street',
#  'Addington Drive',
#  'Addington Grove',
#  'Addington Road',
#  'Addington Square',
#  'Addison Avenue',
#  'Addison Bridge Place',
#  'Addison Crescent',
#  'Addison Drive',
#  'Addison Gardens',
#  'Addison Grove',
#  'Addison Place',
#  'Addison Road',
#  'Addison Terrace',
#  'Addison Way',
#  'Addle Hill',
#  'Addle Street',
#  'Adelaide Avenue',
#  'Adelaide Grove',
#  'Adelaide Road',
#  'Adelaide Street',
#  'Adelaide Walk',
#  'Adelina Grove',
#  'Adelina Mews',
#  'Adeline Place',
#  'Aden Grove',
#  'Aden Terrace',
#  'Adeney Close',
#  'Adenmore Road',
#  'Adie Road',
#  'Adine Road',
#  'Adler Street',
#  'Adley Street',
#  'Adlington Close',
#  'Admaston Road',
#  'Admiral Place',
#  'Admiral Seymour Road',
#  'Admiral Square',
#  'Admiral Street',
#  'Admiral Walk',
#  'Admirals Close',
#  'Admirals Gate',
#  'Admirals Walk',
#  'Admirals Way',
#  'Admiralty Close',
#  'Adolf Street',
#  'Adolphus Road',
#  'Adolphus Street',
#  'Adpar Street',
#  'Adrian Avenue',
#  'Adrian Mews',
#  'Advance Road',
#  'Adys Lawn',
#  'Adys Road',
#  'Aeroville',
#  'Afghan Road',
#  'Aftab Terrace',
#  'Agamemnon Road',
#  'Agar Grove',
#  'Agar Place',
#  'Agar Street',
#  'Agate Close',
#  'Aaron Hill Road',
#  'Abberley Mews',
#  'Abbess Close',
#  'Abbeville Road',
#  'Abbey Drive',
#  'Abbey Gardens',
#  'Abbey Grove',
#  'Abbey Lane',
#  'Abbey Mews',
#  'Abbey Orchard Street',
#  'Abbey Parade',
#  'Abbey Road',
#  'Abbey Street',
#  'Abbey Terrace',
#  'Abbey View',
#  'Abbey Wood Road',
#  'Abbeyfield Estate',
#  'Abbeyfield Road',
#  'Abbeyfields Close',
#  'Abbots Gardens',
#  'Abbots Manor',
#  'Abbots Park',
#  'Abbots Place',
#  'Abbots Road',
#  'Abbots Terrace',
#  'Abbots Walk',
#  'Abbotsbury Close',
#  'Abbotsbury Mews',
#  'Abbotsbury Road',
#  'Abbotsford Avenue',
#  'Abbotshade Road',
#  'Abbotshall Avenue',
#  'Abbotshall Road',
#  'Abbotsleigh Road',
#  'Abbotstone Road',
#  'Abbotswell Road',
#  'Abbotswood Road',
#  'Abbott Avenue',
#  'Abbott Road',
#  'Abbotts Close',
#  'Abbotts Crescent',
#  'Abbotts Park Road',
#  'Abchurch Lane',
#  'Abdale Road',
#  'Aberavon Road',
#  'Abercairn Road',
#  'Abercorn Close',
#  'Abercorn Place',
#  'Abercorn Road',
#  'Abercorn Way',
#  'Abercrombie Street',
#  'Aberdare Gardens',
#  'Aberdeen Lane',
#  'Aberdeen Parade',
#  'Aberdeen Park',
#  'Aberdeen Place',
#  'Aberdeen Road',
#  'Aberdeen Terrace',
#  'Aberdour Street',
#  'Aberfeldy Street',
#  'Aberford Gardens',
#  'Aberfoyle Road',
#  'Abergeldie Road',
#  'Abernethy Road',
#  'Abersham Road',
#  'Abery Street',
#  'Abingdon Close',
#  'Abingdon Road',
#  'Abingdon Villas',
#  'Abinger Grove',
#  'Abinger Mews',
#  'Abinger Road',
#  'Ablett Street',
#  'Abney Gardens',
#  'Abney Park Terrace',
#  'Aboyne Drive',
#  'Aboyne Road',
#  'Abyssinia Close',
#  'Abyssinia Road',
#  'Acacia Avenue',
#  'Acacia Close',
#  'Acacia Gardens',
#  'Acacia Grove',
#  'Acacia Place',
#  'Acacia Road',
#  'Academy Buildings',
#  'Academy Place',
#  'Acanthus Drive',
#  'Acanthus Road',
#  'Accommodation Road',
#  'Acfold Road',
#  'Achilles Close',
#  'Achilles Road',
#  'Achilles Street',
#  'Acklam Road',
#  'Acklington Drive',
#  'Ackmar Road',
#  'Ackroyd Drive',
#  'Ackroyd Road',
#  'Acland Close',
#  'Acland Crescent',
#  'Acland Road',
#  'Acol Road',
#  'Acorn Close',
#  'Acorn Gardens',
#  'Acorn Parade',
#  'Acorn Walk',
#  'Acorn Way',
#  'Acre Drive',
#  'Acre Lane',
#  'Acre Road',
#  'Acris Street',
#  'Acton Close',
#  'Acton Lane',
#  'Acton Street',
#  'Acuba Road',
#  'Acworth Close',
#  'Ada Gardens',
#  'Ada Place',
#  'Ada Road',
#  'Ada Street',
#  'Adair Close',
#  'Adair Road',
#  'Adam & Eve Mews',
#  'Adam Close',
#  'Adam Road',
#  'Adam Street',
#  'Adam Walk',
#  'Adams Close',
#  'Adams Gardens Estate',
#  'Adams Place',
#  'Adams Road',
#  'Adams Row',
#  'Adamson Road',
#  'Adamsrill Road',
#  'Adare Walk',
#  'Adderley Gardens',
#  'Adderley Grove',
#  'Adderley Street',
#  'Addington Drive',
#  'Addington Grove',
#  'Addington Road',
#  'Addington Square',
#  'Addison Avenue',
#  'Addison Bridge Place',
#  'Addison Crescent',
#  'Addison Drive',
#  'Addison Gardens',
#  'Addison Grove',
#  'Addison Place',
#  'Addison Road',
#  'Addison Terrace',
#  'Addison Way',
#  'Addle Hill',
#  'Addle Street',
#  'Adelaide Avenue',
#  'Adelaide Grove',
#  'Adelaide Road',
#  'Adelaide Street',
#  'Adelaide Walk',
#  'Adelina Grove',
#  'Adelina Mews',
#  'Adeline Place',
#  'Aden Grove',
#  'Aden Terrace',
#  'Adeney Close',
#  'Adenmore Road',
#  'Adie Road',
#  'Adine Road',
#  'Adler Street',
#  'Adley Street',
#  'Adlington Close',
#  'Admaston Road',
#  'Admiral Place',
#  'Admiral Seymour Road',
#  'Admiral Square',
#  'Admiral Street',
#  'Admiral Walk',
#  'Admirals Close',
#  'Admirals Gate',
#  'Admirals Walk',
#  'Admirals Way',
#  'Admiralty Close',
#  'Adolf Street',
#  'Adolphus Road',
#  'Adolphus Street',
#  'Adpar Street',
#  'Adrian Avenue',
#  'Adrian Mews',
#  'Advance Road',
#  'Adys Lawn',
#  'Adys Road',
#  'Aeroville',
#  'Afghan Road',
#  'Aftab Terrace',
#  'Agamemnon Road',
#  'Agar Grove',
#  'Agar Place',
#  'Agar Street',
#  'Agate Close',
#  'Agate Road',
#  'Agatha Close',
#  'Agaton Road',
#  'Agdon Street',
#  'Agincourt Road',
#  'Agnes Close',
#  'Agnes Riley Gardens',
#  'Agnes Road',
#  'Agnes Street',
#  'Agnesfield Close',
#  'Agnew Road',
#  'Aileen Walk',
#  'Ailsa Street',
#  'Ainger Mews',
#  'Ainger Road',
#  'Ainsdale Drive',
#  'Ainsdale Road',
#  'Ainsley Close',
#  'Ainsley Street',
#  'Ainslie Walk',
#  'Ainslie Wood Crescent',
#  'Ainslie Wood Gardens',
#  'Ainslie Wood Road',
#  'Ainsty Estate',
#  'Ainsworth Close',
#  'Ainsworth Road',
#  'Ainsworth Way',
#  'Aintree Avenue',
#  'Aintree Estate',
#  'Air Street',
#  'Airdrie Close',
#  'Airedale Avenue',
#  'Airedale Avenue South',
#  'Airedale Road',
#  'Airlie Gardens',
#  'Aisgill Avenue',
#  'Aisher Road',
#  'Aislibie Road',
#  'Aiten Place',
#  'Aitken Close',
#  'Aitken Road',
#  'Ajax Avenue',
#  'Ajax Road',
#  'Akehurst Street',
#  'Akenside Road',
#  'Akerman Road',
#  'Alabama Street',
#  'Alacross Road',
#  'Alan Hocken Way',
#  'Alan Road',
#  'Alander Mews',
#  'Alanthus Close',
#  'Alba Gardens',
#  'Alba Place',
#  'Albacore Crescent',
#  'Alban Highwalk',
#  'Albany',
#  'Albany Close',
#  'Albany Cottages',
#  'Albany Courtyard',
#  'Albany Mews',
#  'Albany Road',
#  'Albany Row',
#  'Albany Street',
#  'Albany Terrace',
#  'Albatross Street',
#  'Albemarle Street',
#  'Albemarle Way',
#  'Alberon Gardens',
#  'Albert Avenue',
#  'Albert Bridge Road',
#  'Albert Carr Gardens',
#  'Albert Close',
#  'Albert Cottages',
#  'Albert Crescent',
#  'Albert Drive',
#  'Albert Embankment',
#  'Albert Gardens',
#  'Albert Gate',
#  'Albert Grove',
#  'Albert Mews',
#  'Albert Place',
#  'Albert Road',
#  'Albert Square',
#  'Albert Street',
#  'Albert Terrace',
#  'Albert Terrace Mews',
#  'Albert Walk',
#  'Albert Way',
#  'Alberta Estate',
#  'Alberta Street',
#  'Albion Avenue',
#  'Albion Close',
#  'Albion Drive',
#  'Albion Estate',
#  'Albion Grove',
#  'Albion Mews',
#  'Albion Parade',
#  'Albion Place',
#  'Albion Road',
#  'Albion Square',
#  'Albion Street',
#  'Albion Terrace',
#  'Albion Villas Road',
#  'Albion Way',
#  'Albion Yard',
#  'Albury Mews',
#  'Albury Street',
#  'Albyn Road',
#  'Alcester Crescent',
#  'Alconbury Road',
#  'Alcott Close',
#  'Aldbourne Road',
#  'Aldbridge Street',
#  'Aldburgh Mews',
#  'Aldbury Mews',
#  'Aldebert Terrace',
#  'Aldeburgh Close',
#  'Aldeburgh Street',
#  'Alden Avenue',
#  'Aldenham Street',
#  'Aldensley Road',
#  'Alder Close',
#  'Alder Grove',
#  'Alder Mews',
#  'Alder Road',
#  'Alderbrook Road',
#  'Alderbury Road',
#  'Alderholt Way',
#  'Aldermans Hill',
#  'Aldermoor Road',
#  'Alderney Road',
#  'Alderney Street',
#  'Alders Close',
#  'Aldersbrook Lane',
#  'Aldersbrook Road',
#  'Aldersgate Street',
#  'Aldersgrove Avenue',
#  'Aldershot Road',
#  'Aldershot Terrace',
#  'Alderton Close',
#  'Alderton Crescent',
#  'Alderton Road',
#  'Alderton Way',
#  'Alderville Road',
#  'Alderwood Road',
#  'Aldford Street',
#  'Aldgate Barrs',
#  'Aldgate High Street',
#  'Aldine Street',
#  'Aldis Mews',
#  'Aldis Street',
#  'Aldred Road',
#  'Aldren Road',
#  'Aldrich Terrace',
#  'Aldriche Way',
#  'Aldridge Road Villas',
#  'Aldridge Walk',
#  'Aldrington Road',
#  'Aldsworth Close',
#  'Aldwick Close',
#  'Aldworth Grove',
#  'Aldworth Road',
#  'Aldwych',
#  'Alesia Close',
#  'Alestan Beck Road',
#  'Alexander Avenue',
#  'Alexander Evans Mews',
#  'Alexander Mews',
#  'Alexander Place',
#  'Alexander Road',
#  'Alexander Square',
#  'Alexander Street',
#  'Alexander Terrace',
#  'Alexandra Avenue',
#  'Alexandra Close',
#  'Alexandra Drive',
#  'Alexandra Gardens',
#  'Alexandra Grove',
#  'Alexandra Mews',
#  'Alexandra Park Road',
#  'Alexandra Place',
#  'Alexandra Road',
#  'Alexandra Street',
#  'Alexandra Walk',
#  'Alexandria Road',
#  'Alexis Street',
#  'Alfearn Road',
#  'Alfoxton Avenue',
#  'Alfred Close',
#  'Alfred Place',
#  'Alfred Road',
#  'Alfred Street',
#  'Alfred Villas',
#  'Alfreda Street',
#  'Alfreton Close',
#  'Alfriston Road',
#  'Algarve Road',
#  'Algernon Road',
#  'Algiers Road',
#  'Agate Road',
#  'Agatha Close',
#  'Agaton Road',
#  'Agdon Street',
#  'Agincourt Road',
#  'Agnes Close',
#  'Agnes Riley Gardens',
#  'Agnes Road',
#  'Agnes Street',
#  'Agnesfield Close',
#  'Agnew Road',
#  'Aileen Walk',
#  'Ailsa Street',
#  'Ainger Mews',
#  'Ainger Road',
#  'Ainsdale Drive',
#  'Ainsdale Road',
#  'Ainsley Close',
#  'Ainsley Street',
#  'Ainslie Walk',
#  'Ainslie Wood Crescent',
#  'Ainslie Wood Gardens',
#  'Ainslie Wood Road',
#  'Ainsty Estate',
#  'Ainsworth Close',
#  'Ainsworth Road',
#  'Ainsworth Way',
#  'Aintree Avenue',
#  'Aintree Estate',
#  'Air Street',
#  'Airdrie Close',
#  'Airedale Avenue',
#  'Airedale Avenue South',
#  'Airedale Road',
#  'Airlie Gardens',
#  'Aisgill Avenue',
#  'Aisher Road',
#  'Aislibie Road',
#  'Aiten Place',
#  'Aitken Close',
#  'Aitken Road',
#  'Ajax Avenue',
#  'Ajax Road',
#  'Akehurst Street',
#  'Akenside Road',
#  'Akerman Road',
#  'Alabama Street',
#  'Alacross Road',
#  'Alan Hocken Way',
#  'Alan Road',
#  'Alander Mews',
#  'Alanthus Close',
#  'Alba Gardens',
#  'Alba Place',
#  'Albacore Crescent',
#  'Alban Highwalk',
#  'Albany',
#  'Albany Close',
#  'Albany Cottages',
#  'Albany Courtyard',
#  'Albany Mews',
#  'Albany Road',
#  'Albany Row',
#  'Albany Street',
#  'Albany Terrace',
#  'Albatross Street',
#  'Albemarle Street',
#  'Albemarle Way',
#  'Alberon Gardens',
#  'Albert Avenue',
#  'Albert Bridge Road',
#  'Albert Carr Gardens',
#  'Albert Close',
#  'Albert Cottages',
#  'Albert Crescent',
#  'Albert Drive',
#  'Albert Embankment',
#  'Albert Gardens',
#  'Albert Gate',
#  'Albert Grove',
#  'Albert Mews',
#  'Albert Place',
#  'Albert Road',
#  'Albert Square',
#  'Albert Street',
#  'Albert Terrace',
#  'Albert Terrace Mews',
#  'Albert Walk',
#  'Albert Way',
#  'Alberta Estate',
#  'Alberta Street',
#  'Albion Avenue',
#  'Albion Close',
#  'Albion Drive',
#  'Albion Estate',
#  'Albion Grove',
#  'Albion Mews',
#  'Albion Parade',
#  'Albion Place',
#  'Albion Road',
#  'Albion Square',
#  'Albion Street',
#  'Albion Terrace',
#  'Albion Villas Road',
#  'Albion Way',
#  'Albion Yard',
#  'Albury Mews',
#  'Albury Street',
#  'Albyn Road',
#  'Alcester Crescent',
#  'Alconbury Road',
#  'Alcott Close',
#  'Aldbourne Road',
#  'Aldbridge Street',
#  'Aldburgh Mews',
#  'Aldbury Mews',
#  'Aldebert Terrace',
#  'Aldeburgh Close',
#  'Aldeburgh Street',
#  'Alden Avenue',
#  'Aldenham Street',
#  'Aldensley Road',
#  'Alder Close',
#  'Alder Grove',
#  'Alder Mews',
#  'Alder Road',
#  'Alderbrook Road',
#  'Alderbury Road',
#  'Alderholt Way',
#  'Aldermans Hill',
#  'Aldermoor Road',
#  'Alderney Road',
#  'Alderney Street',
#  'Alders Close',
#  'Aldersbrook Lane',
#  'Aldersbrook Road',
#  'Aldersgate Street',
#  'Aldersgrove Avenue',
#  'Aldershot Road',
#  'Aldershot Terrace',
#  'Alderton Close',
#  'Alderton Crescent',
#  'Alderton Road',
#  'Alderton Way',
#  'Alderville Road',
#  'Alderwood Road',
#  'Aldford Street',
#  'Aldgate Barrs',
#  'Aldgate High Street',
#  'Aldine Street',
#  'Aldis Mews',
#  'Aldis Street',
#  'Aldred Road',
#  'Aldren Road',
#  'Aldrich Terrace',
#  'Aldriche Way',
#  'Aldridge Road Villas',
#  'Aldridge Walk',
#  'Aldrington Road',
#  'Aldsworth Close',
#  'Aldwick Close',
#  'Aldworth Grove',
#  'Aldworth Road',
#  'Aldwych',
#  'Alesia Close',
#  'Alestan Beck Road',
#  'Alexander Avenue',
#  'Alexander Evans Mews',
#  'Alexander Mews',
#  'Alexander Place',
#  'Alexander Road',
#  'Alexander Square',
#  'Alexander Street',
#  'Alexander Terrace',
#  'Alexandra Avenue',
#  'Alexandra Close',
#  'Alexandra Drive',
#  'Alexandra Gardens',
#  'Alexandra Grove',
#  'Alexandra Mews',
#  'Alexandra Park Road',
#  'Alexandra Place',
#  'Alexandra Road',
#  'Alexandra Street',
#  'Alexandra Walk',
#  'Alexandria Road',
#  'Alexis Street',
#  'Alfearn Road',
#  'Alfoxton Avenue',
#  'Alfred Close',
#  'Alfred Place',
#  'Alfred Road',
#  'Alfred Street',
#  'Alfred Villas',
#  'Alfreda Street',
#  'Alfreton Close',
#  'Alfriston Road',
#  'Algarve Road',
#  'Algernon Road',
#  'Algiers Road',
#  'Alice Lane',
#  'Alice Street',
#  'Alice Thompson Close',
#  'Alice Walker Close',
#  'Alie Street',
#  'Alington Crescent',
#  'Alison Close',
#  'Aliwal Road',
#  'Alkerden Road',
#  'Alkham Road',
#  'All Hallows Road',
#  'All Saints Close',
#  'All Saints Road',
#  'All Saints Street',
#  'All Souls Avenue',
#  'All Souls Place',
#  'Allan Barclay Close',
#  'Allan Way',
#  'Allandale Avenue',
#  'Allanson Court',
#  'Allard Gardens',
#  'Allardyce Street',
#  'Allcroft Road',
#  'Allen Edwards Drive',
#  'Allen Road',
#  'Allen Street',
#  'Allenby Road',
#  'Allendale Close',
#  'Allensbury Place',
#  'Allenswood Road',
#  'Allerford Road',
#  'Allerton Road',
#  'Allerton Walk',
#  'Allestree Road',
#  'Alleyn Crescent',
#  'Alleyn Park',
#  'Alleyn Road',
#  'Allfarthing Lane',
#  'Allhallows Road',
#  'Alliance Road',
#  'Allingham Close',
#  'Allingham Mews',
#  'Allingham Street',
#  'Allington Avenue',
#  'Allington Road',
#  'Allington Street',
#  'Allison Close',
#  'Allison Grove',
#  'Allison Road',
#  'Allitsen Road',
#  'Allnutt Way',
#  'Alloa Road',
#  'Alloway Road',
#  'Allsop Place',
#  'Allum Way',
#  'Allwood Close',
#  'Alma Avenue',
#  'Alma Close',
#  'Alma Grove',
#  'Alma Place',
#  'Alma Road',
#  'Alma Square',
#  'Alma Street',
#  'Alma Terrace',
#  'Almack Road',
#  'Almeida Street',
#  'Almer Road',
#  'Almeric Road',
#  'Almington Street',
#  'Almond Avenue',
#  'Almond Close',
#  'Almond Road',
#  'Almorah Road',
#  'Alnwick Road',
#  'Alperton Street',
#  'Alpha Grove',
#  'Alpha Place',
#  'Alpha Road',
#  'Alpha Street',
#  'Alphabet Square',
#  'Alphea Close',
#  'Alpine Grove',
#  'Alpine Road',
#  'Alpine Way',
#  'Alric Avenue',
#  'Alroy Road',
#  'Alscot Road',
#  'Alscot Way',
#  'Alston Road',
#  'Alt Grove',
#  'Altair Close',
#  'Altash Way',
#  'Altenburg Avenue',
#  'Altenburg Gardens',
#  'Althea Street',
#  'Althorne Gardens',
#  'Althorp Road',
#  'Althorpe Mews',
#  'Altmore Avenue',
#  'Alton Road',
#  'Alton Street',
#  'Alvanley Gardens',
#  'Alverston Gardens',
#  'Alverstone Avenue',
#  'Alverstone Gardens',
#  'Alverstone Road',
#  'Alverton Street',
#  'Alvey Street',
#  'Alvington Crescent',
#  'Alwold Crescent',
#  'Alwyn Avenue',
#  'Alwyn Gardens',
#  'Alwyne Place',
#  'Alwyne Road',
#  'Alwyne Square',
#  'Alwyne Villas',
#  'Alyn Bank',
#  'Alyth Gardens',
#  'Ambassador Gardens',
#  'Ambassador Square',
#  'Amber Avenue',
#  'Amber Court',
#  'Amber Grove',
#  'Amberden Avenue',
#  'Ambergate Street',
#  'Amberley Grove',
#  'Amberley Road',
#  'Amblecote Close',
#  'Amblecote Meadows',
#  'Amblecote Road',
#  'Ambler Road',
#  'Ambleside Avenue',
#  'Ambleside Close',
#  'Ambleside Gardens',
#  'Ambleside Road',
#  'Ambrosden Avenue',
#  'Ambrose Avenue',
#  'Ambrose Close',
#  'Ambrose Mews',
#  'Ambrose Street',
#  'Ambrose Walk',
#  'Amelia Street',
#  'Amen Corner',
#  'Amen Court',
#  'Amerland Road',
#  'Amersham Avenue',
#  'Amersham Grove',
#  'Amersham Road',
#  'Amersham Vale',
#  'Amery Gardens',
#  'Ames Cottages',
#  'Amesbury Avenue',
#  'Amesbury Drive',
#  'Amethyst Road',
#  'Amherst Avenue',
#  'Amherst Gardens',
#  'Amherst Road',
#  'Amhurst Parade',
#  'Amhurst Park',
#  'Amhurst Road',
#  'Amhurst Walk',
#  'Amiel Street',
#  'Amies Street',
#  'Amina Way',
#  'Amity Grove',
#  'Amity Road',
#  'Ammanford Green',
#  'Amner Road',
#  'Amor Road',
#  'Amott Road',
#  'Ampleforth Road',
#  'Ampthill Square',
#  'Ampton Place',
#  'Ampton Street',
#  'Amroth Close',
#  'Amroth Green',
#  'Amsterdam Road',
#  'Amwell Street',
#  'Amy Warne Close',
#  'Amyruth Road',
#  'Anatola Road',
#  'Ancaster Street',
#  'Anchor & Hope Lane',
#  'Anchor Mews',
#  'Anchor Street',
#  'Anchor Yard',
#  'Anchorage Close',
#  'Ancill Close',
#  'Ancona Road',
#  'Andalus Road',
#  'Anderson Close',
#  'Anderson Road',
#  'Anderson Square',
#  'Anderson Street',
#  'Anderton Close',
#  'Andover Avenue',
#  'Andover Place',
#  'Andover Road',
#  'Andre Street',
#  'Andrew Place',
#  ...]
# 1159

# %%
#import string for alphabet
import string
from statistics import mode
import itertools
flatten = itertools.chain.from_iterable

# %%
# %%time
#attempting to scrape the streets for the entire alphabet
list_london_street_names=[]
for letter in list(string.ascii_lowercase):

    london_streetmap='http://london.streetmapof.co.uk/'
    streetmap_url=london_streetmap+letter+'/'


    map_html_text = requests.get(streetmap_url).text
    soup_map = BeautifulSoup(map_html_text, 'lxml')

    #find street names in the map:
    map_ads=soup_map.find_all('td', { "valign": "top" })


    # ad = map_ads[1]
    count_pages=[]
    [count_pages.append(a) for a in soup_map.find_all('a', href=True) if a['href'].startswith(f'/{letter}/')]
    len(count_pages)

    list_starting_with_letter=[]
    if len(count_pages)>0:
        list_starting_with_letter=[]
        for i in range(len(count_pages)):
            if i==0:
                streetmap_url=london_streetmap+letter+'/'

                map_html_text = requests.get(streetmap_url).text
                soup_map = BeautifulSoup(map_html_text, 'lxml')
                map_ads=soup_map.find_all('td', { "valign": "top" })
                for k in range(len(map_ads)):
                    ad = map_ads[k]


                    for a in ad.find_all('a', href=True):
                        if a['href'].startswith(f'/{letter}/'):
                            count_pages.append(a)
                        else:
                            list_starting_with_letter.append(a.get_text(strip=True))
            else:
                streetmap_url=london_streetmap+letter+'/'+str(i+1)

                map_html_text = requests.get(streetmap_url).text
                soup_map = BeautifulSoup(map_html_text, 'lxml')
                map_ads=soup_map.find_all('td', { "valign": "top" })

                for k in range(len(map_ads)):
                    ad = map_ads[k]


                    for a in ad.find_all('a', href=True):
                        if a['href'].startswith(f'/{letter}/'):
                            count_pages.append(a)
                        else:
                            list_starting_with_letter.append(a.get_text(strip=True))
        len(list(set(list_starting_with_letter)))
        list_london_street_names.append(list(set(list_starting_with_letter)))
    else:
        list_starting_with_letter=[]
        streetmap_url=london_streetmap+letter+'/'

        map_html_text = requests.get(streetmap_url).text
        soup_map = BeautifulSoup(map_html_text, 'lxml')
        map_ads=soup_map.find_all('td', { "valign": "top" })
        for k in range(len(map_ads)):
            ad = map_ads[k]


            for a in ad.find_all('a', href=True):
                if a['href'].startswith(f'/{letter}/'):
                    break
                else:
                    list_starting_with_letter.append(a.get_text(strip=True))
        len(list(set(list_starting_with_letter)))
        list_london_street_names.append(list(set(list_starting_with_letter)))
        
list_london_street_names
# Out:
# CPU times: user 8.5 s, sys: 196 ms, total: 8.69 s
# Wall time: 25.6 s
# [['Acris Street',
#   'Avarn Road',
#   'Arborfield Close',
#   'All Saints Close',
#   'Aldrington Road',
#   'Arndale Walk',
#   'Augustus Road',
#   'Ambler Road',
#   'Adair Road',
#   'Aldwick Close',
#   'Albert Carr Gardens',
#   'Archibald Road',
#   'Arctic Street',
#   'Ashlar Place',
#   'Aston Road',
#   'Atheldene Road',
#   'Akenside Road',
#   'Andrews Walk',
#   'Acre Lane',
#   'Aaron Hill Road',
#   'Adys Lawn',
#   'Agnes Street',
#   'Archdale Road',
#   'Aslett Street',
#   'Ashingdon Close',
#   'Armstrong Close',
#   'Arran Drive',
#   'Alkerden Road',
#   'Amyruth Road',
#   'Acland Road',
#   'Ashurst Gardens',
#   'Alexander Mews',
#   'Ackroyd Drive',
#   'Ancona Road',
#   'Alt Grove',
#   'Arden Crescent',
#   'Anderson Close',
#   'Acacia Road',
#   'Admirals Walk',
#   'Argyll Street',
#   'Abbeville Road',
#   'Adelaide Road',
#   'Achilles Road',
#   'Alderton Crescent',
#   'Allhallows Road',
#   'Ann Moss Way',
#   'Arica Road',
#   'Amblecote Close',
#   'Apple Tree Yard',
#   'Arkell Grove',
#   'Anderton Close',
#   'Amherst Avenue',
#   'Ash Road',
#   'Ashridge Gardens',
#   'Ashtead Road',
#   'Ascham Street',
#   'Abyssinia Close',
#   'Alder Close',
#   'Abbots Park',
#   'Admiral Seymour Road',
#   'Augustine Road',
#   'Alwyne Square',
#   'Athelstan Gardens',
#   'Acworth Close',
#   'Ashley Gardens',
#   'Alderville Road',
#   'Alice Street',
#   'Ashburn Place',
#   'Aiten Place',
#   'Admiral Place',
#   'Alfearn Road',
#   'Althea Street',
#   'Ashby Grove',
#   'Acklam Road',
#   'Albert Bridge Road',
#   'Arterberry Road',
#   'Ashcombe Road',
#   'Arthur Horsley Walk',
#   'Agdon Street',
#   'Aylmer Road',
#   'Arragon Gardens',
#   'Albert Road',
#   'Alnwick Road',
#   'Argyle Walk',
#   'Autumn Close',
#   'Armistice Gardens',
#   'Auriol Road',
#   'Alberta Estate',
#   'Allington Avenue',
#   'Abdale Road',
#   'Aisgill Avenue',
#   'Abinger Mews',
#   'Annette Road',
#   'Ashdown',
#   'Addison Drive',
#   'Acre Drive',
#   'Anselm Road',
#   'Arnold Circus',
#   'Ashchurch Grove',
#   'Alleyn Road',
#   'Audrey Street',
#   'Avenue Gardens',
#   'Andover Place',
#   'Avonmore Road',
#   'Alderton Road',
#   'Aquila Street',
#   'Ambleside Avenue',
#   'Annesley Close',
#   'Annington Road',
#   'Almer Road',
#   'Aytoun Road',
#   'Aubyn Hill',
#   'Almond Avenue',
#   'Amhurst Walk',
#   'Alfred Road',
#   'Alphabet Square',
#   'Ardlui Road',
#   'Albert Mews',
#   'April Glen',
#   'Alden Avenue',
#   'Ashenden Road',
#   'Abbotts Park Road',
#   'Alleyn Park',
#   'Abercrombie Street',
#   'Albert Embankment',
#   'Alton Road',
#   'Abbeyfields Close',
#   'Aboyne Road',
#   'Ashbourne Way',
#   'Abergeldie Road',
#   'Arcadia Street',
#   'Abbotsleigh Road',
#   'Arncliffe Close',
#   'Achilles Street',
#   'Anerley Park Road',
#   'Arden Road',
#   'Ambassador Square',
#   'Ashcroft Court',
#   'Algernon Road',
#   'Archery Close',
#   'Alderbrook Road',
#   'Atlas Mews',
#   'Anson Road',
#   'Argyle Road',
#   'Andre Street',
#   'Appleby Road',
#   'Aldersgrove Avenue',
#   'Ampleforth Road',
#   'Aberdeen Terrace',
#   'Alfred Villas',
#   'Ashcombe Street',
#   'Allen Edwards Drive',
#   'Ashfield Parade',
#   'Ashton Road',
#   'Alan Hocken Way',
#   'Arundel Terrace',
#   'Argon Road',
#   'Alder Grove',
#   'Adamson Road',
#   'Andrew Place',
#   'Alexander Place',
#   'Allan Way',
#   'Atlas Gardens',
#   'Albemarle Street',
#   'Albert Close',
#   'Angel Road',
#   'Ashburton Road',
#   'Adine Road',
#   'Asylum Road',
#   'Arborfield House',
#   'Arnould Avenue',
#   'Addison Bridge Place',
#   'Abercorn Way',
#   'Admirals Gate',
#   'Ampton Place',
#   'Abbey Road',
#   'Arden Mews',
#   'Alice Lane',
#   'Annabel Close',
#   'Acacia Gardens',
#   'Allardyce Street',
#   'Aston Street',
#   'Althorne Gardens',
#   'Ansleigh Place',
#   'Archel Road',
#   'Avril Way',
#   'Aldbourne Road',
#   'Akehurst Street',
#   'Arkindale Road',
#   'Almington Street',
#   'Ashley Walk',
#   'Asland Road',
#   'Ashbridge Street',
#   'Annsworthy Crescent',
#   'Azalea Close',
#   'Alderney Street',
#   'Asmuns Hill',
#   'Averill Street',
#   'Albert Terrace Mews',
#   'Ascot Parade',
#   'Avondale Pavement',
#   'Aberfoyle Road',
#   'Ashworth Road',
#   'Asmara Road',
#   'Aberdare Gardens',
#   'All Hallows Road',
#   'Ainsdale Road',
#   'Ackmar Road',
#   'Alma Avenue',
#   'Albion Estate',
#   'Academy Place',
#   'Albany Terrace',
#   'Altair Close',
#   'Agar Place',
#   'Angel Walk',
#   'Anvil Close',
#   'Ascot Road',
#   'Alderton Close',
#   'Allfarthing Lane',
#   'Aylesford Street',
#   'Ashdown Crescent',
#   'Auburn Close',
#   'Albany Cottages',
#   'Avonmouth Street',
#   'Amberley Road',
#   'Aspley Road',
#   'Arlington Way',
#   'Aspinden Road',
#   'Archer Street',
#   'Ashridge Crescent',
#   'Athlone Street',
#   'Alexander Evans Mews',
#   'Askew Road',
#   'Alexander Street',
#   'Anderson Street',
#   'Aylesham Close',
#   'Aldensley Road',
#   'Ainslie Wood Gardens',
#   'Albemarle Way',
#   'Ampthill Square',
#   'Allison Grove',
#   'Armitage Road',
#   'Argyle Passage',
#   'Acorn Parade',
#   'Alverton Street',
#   'Arneway Street',
#   'Arnhem Place',
#   'Abinger Road',
#   'Aberdeen Lane',
#   'Abery Street',
#   'Ainslie Wood Crescent',
#   'Agaton Road',
#   'Alander Mews',
#   'Aldersbrook Lane',
#   'Arminger Road',
#   'Avondale Rise',
#   'Audley Close',
#   'Avenell Road',
#   'Ashbourne Road',
#   'Ashmole Place',
#   'Angus Street',
#   'Astoria Walk',
#   'Abingdon Road',
#   'Ainsworth Road',
#   'Alwyne Place',
#   'Avenue Mews',
#   'Acton Street',
#   'Archway Street',
#   'Aprey Gardens',
#   'Atherstone Mews',
#   'Abersham Road',
#   'All Saints Road',
#   'Arkwright Road',
#   'Avignon Road',
#   'Academy Buildings',
#   'Acland Close',
#   'Ashbrook Road',
#   'Airedale Avenue South',
#   'Ashmole Street',
#   'Amethyst Road',
#   'Arlington Street',
#   'Anglesea Avenue',
#   'Avondale Court',
#   'Angles Road',
#   'Anley Road',
#   'Allwood Close',
#   'Arbor Court',
#   'Arngask Road',
#   'Alfred Street',
#   'Aulton Place',
#   'Alexandra Gardens',
#   'Alban Highwalk',
#   'Airedale Road',
#   'Ansdell Terrace',
#   'Aitken Close',
#   'Ayres Close',
#   'Annis Road',
#   'Adolphus Street',
#   'Ashwood Road',
#   'Aldeburgh Street',
#   "Ann's Close",
#   'Allenby Road',
#   'Alverston Gardens',
#   'Augustus Street',
#   'Amor Road',
#   'Avon Road',
#   'Ainsdale Drive',
#   'Aberdeen Park',
#   'Astle Street',
#   'Attfield Close',
#   'Amina Way',
#   'Admirals Way',
#   'Aylesbury Close',
#   'Aden Grove',
#   'Audley Court',
#   'Aylett Road',
#   'Abbey Parade',
#   'Acre Road',
#   'Allen Road',
#   'Archbishops Place',
#   'Alexandra Road',
#   'Arden Estate',
#   'Amiel Street',
#   'Alperton Street',
#   'Abercorn Place',
#   'Allen Street',
#   'Anns Place',
#   'Arbury Terrace',
#   'Ardwick Road',
#   'Arodene Road',
#   'Alexandra Park Road',
#   'Alwyne Villas',
#   'Abbeyfield Estate',
#   'Abbey Grove',
#   'Ashburton Grove',
#   'Aylward Street',
#   'Adeline Place',
#   'Abingdon Close',
#   'Alscot Way',
#   'Abercorn Close',
#   'Asteys Row',
#   'Aldrich Terrace',
#   'Arlesford Road',
#   'Abinger Grove',
#   'Alwold Crescent',
#   'Ankerdine Crescent',
#   'Aitken Road',
#   'Anna Neagle Close',
#   'Annandale Road',
#   'Arabia Close',
#   'Averil Grove',
#   'Aveling Park Road',
#   'Anstridge Road',
#   'Antelope Road',
#   'April Close',
#   'Admirals Close',
#   'Appleby Street',
#   'Abbotsbury Mews',
#   'Albany Mews',
#   'Addison Way',
#   'Albion Yard',
#   'Aubrey Place',
#   'Alice Walker Close',
#   'Abberley Mews',
#   'Aintree Avenue',
#   'Alvey Street',
#   'Anderson Road',
#   'Addle Hill',
#   'Abercairn Road',
#   'Ansdell Road',
#   'Amesbury Drive',
#   'Agate Close',
#   'Almeida Street',
#   'Arcola Street',
#   'Alloway Road',
#   'Ashchurch Park Villas',
#   'Amber Avenue',
#   'Assata Mews',
#   'Aldren Road',
#   'Ammanford Green',
#   'Asolando Drive',
#   'Avalon Close',
#   'Ashley Place',
#   'Ashmore Road',
#   'Alyn Bank',
#   'Alington Crescent',
#   'Ambrose Street',
#   'Ardley Close',
#   'Ann Street',
#   'Alder Road',
#   'Argyll Road',
#   'Ashmount Estate',
#   'Austral Street',
#   'Avocet Mews',
#   'Adderley Grove',
#   'Ashdown Walk',
#   'Aldridge Road Villas',
#   'Apple Blossom Court',
#   'Adrian Mews',
#   'Applegarth Road',
#   'Aldermans Hill',
#   'Atlantic Road',
#   'Ashby Mews',
#   'Armagh Road',
#   'Aspinall Road',
#   'Alma Close',
#   'Agnes Close',
#   'Ainsworth Way',
#   'Amsterdam Road',
#   'Acanthus Road',
#   'Allerford Road',
#   'Ardfern Avenue',
#   'Audley Square',
#   'Arlington Gardens',
#   'Ashburnham Road',
#   'Arnhem Way',
#   'Albion Parade',
#   'Anglian Road',
#   'Albion Drive',
#   'Aldenham Street',
#   'Amen Corner',
#   'Archangel Street',
#   'Aylwin Estate',
#   'Adrian Avenue',
#   'Ambergate Street',
#   'Allenswood Road',
#   'Ashlin Road',
#   'Airdrie Close',
#   'Albion Street',
#   'Ashbridge Road',
#   'Abchurch Lane',
#   'Ashburn Gardens',
#   'Albion Mews',
#   'Aldworth Grove',
#   'Adam & Eve Mews',
#   'Avondale Avenue',
#   'Avondale Square',
#   'Amersham Road',
#   'Askham Road',
#   'Aldgate Barrs',
#   'Amery Gardens',
#   'Ambleside Close',
#   'Ayrsome Road',
#   'Allcroft Road',
#   'Aldeburgh Close',
#   'Alvanley Gardens',
#   'Ardmere Road',
#   'Aftab Terrace',
#   'Abbotsbury Road',
#   'All Souls Avenue',
#   'Anglo Road',
#   'Aisher Road',
#   'Anfield Close',
#   'Algarve Road',
#   'Aycliffe Road',
#   'Archery Steps',
#   'Amersham Avenue',
#   'Adelina Mews',
#   'Abbotstone Road',
#   'Aberavon Road',
#   'Alexandra Close',
#   'Appleton Road',
#   'Adam Road',
#   'Aldine Street',
#   'Allestree Road',
#   'Ashfield Road',
#   'Auckland Road',
#   'Admiral Square',
#   'Alston Road',
#   'Ashurst Road',
#   'Arthurdon Road',
#   'Andover Avenue',
#   'Arbuthnot Road',
#   'Albert Cottages',
#   'Arlington Place',
#   'Ambleside Gardens',
#   'Attewood Avenue',
#   'Askill Drive',
#   'Annesley Avenue',
#   'Ashmead Road',
#   'Audley Road',
#   'Alfriston Road',
#   'Arabin Road',
#   'Ashbourne Grove',
#   'Albany',
#   'Apple Road',
#   'Argyle Close',
#   'Avington Grove',
#   'Adpar Street',
#   'Ashbourne Close',
#   'Alexander Avenue',
#   'Amhurst Park',
#   'Amber Grove',
#   'Albany Street',
#   'Ada Gardens',
#   'Azania Mews',
#   'Amies Street',
#   'Avocet Close',
#   'Ainsley Street',
#   'Allingham Street',
#   'Asplins Villas',
#   'Agate Road',
#   'Artillery Place',
#   'Arbroath Road',
#   'Ash Tree Dell',
#   'Albion Place',
#   'Anerley Vale',
#   'Arvon Road',
#   'Adam Street',
#   'Alpha Place',
#   'Aylmer Parade',
#   'Arne Walk',
#   'Alyth Gardens',
#   'Ariel Road',
#   'Austin Road',
#   'Avonmore Place',
#   'Avebury Road',
#   'Atlas Road',
#   'Avening Road',
#   'Atterbury Road',
#   'Alpha Street',
#   'Alpine Way',
#   'Atwater Close',
#   'Agnew Road',
#   'Almack Road',
#   'Amblecote Road',
#   'Austell Gardens',
#   'Alverstone Road',
#   'Alders Close',
#   'Abbott Road',
#   'Alwyn Gardens',
#   'Avery Row',
#   'Austin Friars',
#   'Angel Close',
#   'Adelaide Avenue',
#   'Ashby Road',
#   'Abbey Orchard Street',
#   'Alma Place',
#   'Annesley Walk',
#   'Ashen Grove',
#   'Althorpe Mews',
#   'Adler Street',
#   'Adderley Gardens',
#   'Adamsrill Road',
#   'Annie Besant Close',
#   'Arbor Road',
#   'Althorp Road',
#   'Acklington Drive',
#   'Ardent Close',
#   'Azof Street',
#   'Amity Grove',
#   'Angell Road',
#   'Athens Gardens',
#   'Argyle Place',
#   'Askew Villas',
#   'Ashdon Road',
#   'Anchor Street',
#   'Astrop Terrace',
#   'Atherton Road',
#   'Augurs Lane',
#   'Aldbridge Street',
#   'Antrim Road',
#   'Allandale Avenue',
#   'Avenue Park Road',
#   'Ashmount Terrace',
#   'Ardfillan Road',
#   'Albert Crescent',
#   'Ada Street',
#   'Ardleigh Terrace',
#   'Agar Street',
#   'Albury Street',
#   'All Saints Street',
#   'Anglia Walk',
#   'Addington Road',
#   'Argyle Square',
#   'Arthur Street',
#   'Ashen',
#   'Aldebert Terrace',
#   'Athenlay Road',
#   'Aubert Road',
#   'Archway Road',
#   'Asmuns Place',
#   'Arcadia Avenue',
#   'Aberdeen Road',
#   'Adams Row',
#   'Aldridge Walk',
#   'Alderholt Way',
#   'Attneave Street',
#   'Australia Road',
#   'Aislibie Road',
#   'Andwell Close',
#   'Albion Avenue',
#   'Audley Drive',
#   'Alexandra Place',
#   'Alderney Road',
#   'Alderbury Road',
#   'Amberley Grove',
#   'Antill Road',
#   'Apollo Place',
#   'Admiral Street',
#   'Ashdown Way',
#   'Assembly Passage',
#   'Arsenal Road',
#   'Ashwin Street',
#   'Ashlake Road',
#   'Acorn Way',
#   'Arran Walk',
#   'Astell Street',
#   'Atherden Road',
#   'Agar Grove',
#   'Allum Way',
#   'Aberdeen Parade',
#   'Axminster Road',
#   'Ainsley Close',
#   'Augustus Close',
#   'Aldis Mews',
#   'Anerley Hill',
#   'Aubrey Road',
#   'Alfred Close',
#   'Arlington Avenue',
#   'Alma Grove',
#   'Andrews Road',
#   'Aylesbury Street',
#   'Aden Terrace',
#   'Arlesey Close',
#   'Arthingworth Street',
#   'Angell Park Gardens',
#   'Aubyn Square',
#   'Albyn Road',
#   'Atalanta Street',
#   'Abney Gardens',
#   'Athenaeum Place',
#   'Aldford Street',
#   'Alcott Close',
#   'Athelstane Grove',
#   'Alma Square',
#   'Almond Close',
#   'Allerton Walk',
#   'Alesia Close',
#   'Abbotswell Road',
#   'Agatha Close',
#   'Acton Lane',
#   'Alan Road',
#   'Atherton Street',
#   'Amherst Gardens',
#   'Aldershot Terrace',
#   'Adams Place',
#   'Ashworth Close',
#   'Apprentice Way',
#   'Addison Grove',
#   'Arbour Square',
#   'Abbots Road',
#   'Adam Close',
#   'Archibald Street',
#   'Aveline Street',
#   'Alma Road',
#   'Anglers Lane',
#   'Addington Grove',
#   'Allington Street',
#   'Atherton Mews',
#   'Avon Way',
#   'Andover Road',
#   'Arnold Road',
#   'Aske Street',
#   'Antlers Hill',
#   'Ashlone Road',
#   'Ariel Way',
#   'Ascham End',
#   'Alfreda Street',
#   'Assam Street',
#   'Addison Place',
#   'Afghan Road',
#   'Archer Square',
#   'Avenue Parade',
#   'Alexandra Avenue',
#   'Alverstone Avenue',
#   'Ampton Street',
#   'Angell Town Estate',
#   'Antill Terrace',
#   'Appleford Road',
#   'Avondale Park Road',
#   'Aldbury Mews',
#   'Abingdon Villas',
#   'Avenue Close',
#   'Anning Street',
#   'Allison Close',
#   'Amhurst Parade',
#   'Abyssinia Road',
#   'Akerman Road',
#   'Alverstone Gardens',
#   'Archer Road',
#   'Ainslie Wood Road',
#   'Abbey Drive',
#   'Arundel Gardens',
#   'Adley Street',
#   'Adeney Close',
#   'Antrobus Road',
#   'Abbess Close',
#   'Attlee Terrace',
#   'Abbots Manor',
#   'Avenue Crescent',
#   'Ashley Crescent',
#   'Anhalt Road',
#   'Aubrey Walk',
#   'Allingham Close',
#   'Allnutt Way',
#   'Admiral Walk',
#   'Ashington Road',
#   'Astbury Road',
#   'Alexander Road',
#   'Addison Terrace',
#   'Agincourt Road',
#   'Altmore Avenue',
#   'Alroy Road',
#   'Atkins Road',
#   'Appleby Close',
#   'Ashbury Road',
#   'Annesley Road',
#   'Arden Court Gardens',
#   'Adderley Street',
#   'Ainslie Walk',
#   'Alliance Road',
#   'Alfred Place',
#   'Ashbourne Terrace',
#   'Acacia Avenue',
#   'Arran Road',
#   'Ayres Street',
#   'Allingham Mews',
#   'Allington Road',
#   'Aste Street',
#   'Appold Street',
#   'Ardbeg Road',
#   'Amelia Street',
#   'Abercorn Road',
#   'Algiers Road',
#   'Ashford Road',
#   'Anton Street',
#   'Abbey Gardens',
#   'Ajax Road',
#   'Albert Street',
#   'Anderson Square',
#   'Artillery Passage',
#   'Aviary Close',
#   'Alexandria Road',
#   'Arnos Grove',
#   'Archway Close',
#   "Arnull's Road",
#   'Avon Court',
#   'Abbotsford Avenue',
#   'Ashurst Close',
#   'Athelney Street',
#   'Arnside Street',
#   'Ashburnham Close',
#   'Alcester Crescent',
#   'Appledore Close',
#   'Abbey View',
#   'Armoury Way',
#   'Astwood Mews',
#   'Aylton Estate',
#   'Alkham Road',
#   'Acol Road',
#   'Ambleside Road',
#   'Andrewes Gardens',
#   'Angel Road Works',
#   'Alexandra Mews',
#   'Alexis Street',
#   'Abbots Walk',
#   'Atherfold Road',
#   'Ainger Mews',
#   'Alacross Road',
#   'Avalon Road',
#   'Abbotsbury Close',
#   'Ashley Road',
#   'Alpine Grove',
#   'Aberfeldy Street',
#   'Alexandra Drive',
#   'Argyle Way',
#   'Ashville Road',
#   'Adams Gardens Estate',
#   'Arrow Road',
#   'Acanthus Drive',
#   'Ailsa Street',
#   'Abbey Mews',
#   'Alloa Road',
#   'Arabella Drive',
#   'Ardilaun Road',
#   'Admiralty Close',
#   'Arundel Square',
#   'Aberdour Street',
#   'Avery Hill Road',
#   'Addington Drive',
#   'Allitsen Road',
#   'Alpine Road',
#   'Albert Place',
#   'Addison Gardens',
#   'Alconbury Road',
#   'Arnewood Close',
#   'Augusta Street',
#   'Acacia Place',
#   'Agnes Riley Gardens',
#   'Amwell Street',
#   'Abbotshade Road',
#   'Artisan Close',
#   'Ashmill Street',
#   'Ardleigh Road',
#   'Avenons Road',
#   'Abbotshall Road',
#   'Aldred Road',
#   'Adys Road',
#   'Alwyn Avenue',
#   'Ancaster Street',
#   'Amersham Grove',
#   'Albany Row',
#   'Albion Close',
#   'Andrews Place',
#   'Anerley Grove',
#   'Alberta Street',
#   'Abernethy Road',
#   'Anne Street',
#   'Ashburnham Grove',
#   'Albion Villas Road',
#   'Albany Courtyard',
#   'Arkley Crescent',
#   'Ashfield Street',
#   'Avonley Road',
#   'Ascott Avenue',
#   'Abbots Gardens',
#   'Ainsworth Close',
#   'Andalus Road',
#   'Apex Parade',
#   'Alexander Terrace',
#   'Alpha Road',
#   'Asher Way',
#   'Adie Road',
#   'Ashford Avenue',
#   'Armadale Close',
#   'Attlee Road',
#   'Aynhoe Road',
#   'Angelica Drive',
#   'Aldersbrook Road',
#   'Anglia Close',
#   'Ashby Street',
#   'Ascham Drive',
#   'Adelaide Grove',
#   'Amesbury Avenue',
#   'Artichoke Place',
#   'Ambrose Walk',
#   'Albion Road',
#   'Ashleigh Road',
#   'Arnold Gardens',
#   'Anerley Park',
#   'Asher Loftus Way',
#   'Asplins Road',
#   'Avening Terrace',
#   'Aldersgate Street',
#   'Ansar Gardens',
#   'Alexandra Street',
#   'Adolf Street',
#   'Apsley Way',
#   'Alison Close',
#   'Arundel Close',
#   'Ash Grove',
#   'Athelstane Mews',
#   'Angel Mews',
#   'Aylestone Avenue',
#   'Albury Mews',
#   'Adolphus Road',
#   'Arnett Square',
#   'Angel Corner Parade',
#   'Askew Crescent',
#   'Avoca Road',
#   'Antrim Grove',
#   'Alvington Crescent',
#   'Avis Square',
#   'Artillery Lane',
#   'Albert Terrace',
#   'Ashbourne Parade',
#   'Ashchurch Terrace',
#   'Austin Close',
#   'Allerton Road',
#   'Alton Street',
#   'Antigua Walk',
#   'Arlington',
#   'Artesian Walk',
#   'Alfreton Close',
#   'Arkley Road',
#   'Ada Road',
#   'Arundel Street',
#   'Almond Road',
#   'Ambrose Avenue',
#   'Alba Gardens',
#   'Alpha Grove',
#   'Aileen Walk',
#   'Ackroyd Road',
#   'Adelaide Walk',
#   'Addle Street',
#   'Anna Close',
#   'Ashley Lane',
#   'Athlone Road',
#   'Allard Gardens',
#   'Amner Road',
#   'Aintree Estate',
#   'Acland Crescent',
#   'Angel Place',
#   'Arklow Road',
#   'Auckland Close',
#   'Artesian Close',
#   'Amblecote Meadows',
#   'Altenburg Avenue',
#   'Ansell Road',
#   'Adelina Grove',
#   'Arbery Road',
#   'Achilles Close',
#   'Acacia Close',
#   'Aldsworth Close',
#   'Ashburnham Place',
#   'Arthur Grove',
#   'Abbott Avenue',
#   'Albion Grove',
#   'Albert Gate',
#   'Allison Road',
#   'Anthony Road',
#   'Albion Terrace',
#   'Athol Square',
#   'Aldershot Road',
#   'Applewood Close',
#   'Albany Road',
#   'Aylesbury Road',
#   'Aysgarth Road',
#   'Aberford Gardens',
#   'Ainger Road',
#   'Ambrose Close',
#   'Air Street',
#   'Athenaeum Road',
#   'Albert Square',
#   'Albert Way',
#   'Amott Road',
#   'Atwell Road',
#   'Abbey Street',
#   'Abbeyfield Road',
#   'Argyll Close',
#   'Anglesea Terrace',
#   'Armadale Road',
#   'Alderton Way',
#   'Aston Terrace',
#   'Aristotle Road',
#   'Ambrose Mews',
#   'Atterbury Street',
#   'Amber Court',
#   'Aliwal Road',
#   'Ajax Avenue',
#   'Aldgate High Street',
#   'Albany Close',
#   'Approach Close',
#   'Athlone Close',
#   'Angus Gardens',
#   'Apollo Way',
#   'Arcade Chambers',
#   'Amy Warne Close',
#   'Acton Close',
#   'Alwyne Road',
#   'Albert Walk',
#   'Albion Way',
#   'Alexander Square',
#   'Astley Avenue',
#   'Anatola Road',
#   'Arnos Road',
#   'Abbey Terrace',
#   'Alric Avenue',
#   'Awlfield Avenue',
#   'Ashvale Road',
#   'Allanson Court',
#   'Adelaide Street',
#   'Acacia Grove',
#   'Anthony Close',
#   'Ashdale Road',
#   'Amity Road',
#   'Ascalon Street',
#   'Armstrong Court',
#   'Amberden Avenue',
#   'Amroth Green',
#   'Astrop Mews',
#   'Azenby Road',
#   'Adlington Close',
#   'Amhurst Road',
#   'Alanthus Close',
#   'Adams Road',
#   'Ancill Close',
#   'Ashness Road',
#   'Adenmore Road',
#   'Ardmere Cottages',
#   'Aspern Grove',
#   'Addison Avenue',
#   'Agnes Road',
#   'Anchorage Close',
#   'Aubert Park',
#   'Ashmere Grove',
#   'Anchor & Hope Lane',
#   'Artesian Road',
#   'Arches',
#   ...],
#  ['Barringer Square',
#   'Bellgate Mews',
#   'Browns Road',
#   'Bigwood Road',
#   'Birdlip Close',
#   'Britannia Walk',
#   'Bolney Street',
#   'Bushberry Road',
#   'Blythe Hill Place',
#   'Bridstow Place',
#   'Buckingham Palace Road',
#   'Bidwell Gardens',
#   'Batoum Gardens',
#   'Broadley Terrace',
#   'Bisson Road',
#   'Bear Street',
#   'Biddulph Road',
#   'Barnfield Close',
#   'Birchwood Drive',
#   'Brantwood Close',
#   'Bungalow Road',
#   'Bard Road',
#   'Bennett Park',
#   'Barstow Crescent',
#   'Barnsdale Avenue',
#   'Blair Close',
#   'Bellingham Road',
#   'Battersea Rise',
#   'Blessington Close',
#   'Bonding Yard Walk',
#   'Bland Street',
#   'Birchanger Road',
#   'Broad Lawn',
#   'Bryantwood Road',
#   'Brierly Gardens',
#   'Burns Close',
#   'Brackley Terrace',
#   'Buckland Crescent',
#   'Bowling Green Street',
#   'Bill Hamling Close',
#   'Bishops Grove',
#   'Bingham Street',
#   'Baltic Street East',
#   'Burtwell Lane',
#   'Boscombe Close',
#   'Bourchier Street',
#   'Brixton Station Road',
#   'Bressey Grove',
#   'Bristol Gardens',
#   'Barrington Walk',
#   'Brownlow Street',
#   'Broad Court',
#   'Belfry Close',
#   'Bourne Hill',
#   'Bessborough Street',
#   'Burtonhole Close',
#   'Blackfriars Road',
#   'Bramshaw Road',
#   'Bodmin Street',
#   'Burr Road',
#   'Briary Close',
#   'Berry Lane',
#   'Burnels Avenue',
#   'Briar Walk',
#   'Buchanan Close',
#   'Bala Green',
#   'Booth Road',
#   'Bridewain Street',
#   'Brightside Road',
#   'Boxworth Close',
#   'Bedford Square',
#   'Brandram Mews',
#   'Burrows Road',
#   'Breer Street',
#   'Berkley Road',
#   'Benjafield Close',
#   'Bosun Close',
#   'Boyson Road',
#   'Balaam Street',
#   'Buckingham Mews',
#   'Beaulieu Avenue',
#   'Brookdene Road',
#   'Basil Gardens',
#   'Byron Mews',
#   'Brick Street',
#   'Burges Grove',
#   'Batemans Corner',
#   'Barry Avenue',
#   'Bramshill Road',
#   'Barrowfield Close',
#   'Brathway Road',
#   'Broadgate Road',
#   'Buck Lane',
#   'Bishops Road',
#   'Barnes Terrace',
#   'Burdett Mews',
#   'Britten Close',
#   'Beaver Close',
#   'Buckrell Road',
#   'Barnard Hill',
#   'Broughton Road',
#   'Bendmore Avenue',
#   'Burnham Road',
#   'Buckingham Close',
#   'Bulwer Street',
#   'Bradshaw Close',
#   'Brackley Road',
#   'Bredgar Road',
#   'Brentmead Place',
#   'Belinda Road',
#   'Brompton Arcade',
#   'Brown Street',
#   'Brockley Cross',
#   'Brooks Close',
#   'Blacklands Terrace',
#   'Buckleigh Way',
#   'Blantyre Street',
#   'Belmont Hall Court',
#   'Balvaird Place',
#   'Bittern Place',
#   'Belvedere Strand',
#   'Belsize Square',
#   'Bryan Road',
#   'Beaconsfield Cottages',
#   'Bastion Road',
#   'Bathgate Road',
#   'Baroness Road',
#   'Birnam Road',
#   'Broad Common Estate',
#   'Beak Street',
#   'Brougham Street',
#   'Bushey Hill Road',
#   'Belgrave Road',
#   'Beaumont Rise',
#   'Buttermere Close',
#   'Barry Road',
#   'Barnardo Street',
#   'Bertram Cottages',
#   'Barnes Street',
#   'Bradley Close',
#   'Briarbank Road',
#   'Bishop Woods Almshouses',
#   'Baron Close',
#   'Brook Walk',
#   'Barton Close',
#   'Bramham Gardens',
#   'Berenger Walk',
#   'Bramley Road',
#   'Bylands Close',
#   'Brookdale Road',
#   'Bethwin Road',
#   'Beaufort Mews',
#   'Butchers Road',
#   'Bridgeport Place',
#   'Butlers & Colonial Wharf',
#   'Bentham Road',
#   'Brooklyn Avenue',
#   'Balcorne Street',
#   'Boveney Road',
#   'Blackbird Hill',
#   'Bomore Road',
#   'Bird In Bush Road',
#   'Barney Close',
#   'Brookfield Road',
#   'Barretts Grove',
#   'Biggin Way',
#   'Brindwood Road',
#   'Blackwall Way',
#   'Baden Road',
#   'Bowie Close',
#   'Belsize Grove',
#   'Bradshaw Cottages',
#   'Bourne Street',
#   'Bradgate Road',
#   'Brightman Road',
#   'Brockley Rise',
#   'Bective Road',
#   'Bevin Close',
#   'Burtop Way',
#   'Brent Way',
#   'Brownhill Road',
#   'Brompton Terrace',
#   'Birbetts Road',
#   'Beulah Path',
#   'Brook Street',
#   'Brough Close',
#   'Baudwin Road',
#   'Baxter Road',
#   'Beecholme Estate',
#   'Branksome Avenue',
#   'Boundary Lane',
#   'Burrage Grove',
#   'Bedgebury Gardens',
#   'Boycroft Avenue',
#   'Bankside',
#   'Balmoral Mews',
#   'Brockenhurst Gardens',
#   'Braybrook Street',
#   'Botolph Alley',
#   'Butcher Row',
#   'Bowditch',
#   'Bushbaby Close',
#   'Buxton Gardens',
#   'Burder Road',
#   'Beaufoy Walk',
#   'Boades Mews',
#   'Barriedale',
#   'Batavia Road',
#   'Binden Road',
#   'Bordars Road',
#   'Brett Road',
#   'Browning Mews',
#   'Beswick Mews',
#   'Blore Close',
#   'Broadlands Close',
#   'Barrow Close',
#   'Brydon Walk',
#   'Bradley Stone Road',
#   'Brownlow Mews',
#   'Basevi Way',
#   'Barset Road',
#   'Brewhouse Street',
#   'Burbage Close',
#   'Busby Place',
#   'Barnet Grove',
#   'Beatrice Close',
#   'Byron Close',
#   'Bunhouse Place',
#   'Becket Close',
#   'Bailey Close',
#   'Bernard Cassidy Street',
#   'Bowland Yard',
#   'Boston Gardens',
#   'Bexley Gardens',
#   'Booths Place',
#   'Broadway Court',
#   'Bawtry Road',
#   'Belgrave Place',
#   'Bradfield Road',
#   'Blue Ball Yard',
#   'Beaufort Close',
#   'Burrard Road',
#   'Buckstone Road',
#   'Broad Lane',
#   'Beech Way',
#   'Beacons Close',
#   'Bodnant Gardens',
#   'Bushmead Close',
#   'Bassett Street',
#   'Brinton Walk',
#   'Belvoir Road',
#   'Bramble Close',
#   'Belmont Close',
#   'Bourne Terrace',
#   'Bruges Place',
#   'Bayne Close',
#   'Brandon Mews',
#   'Beverley Court',
#   'British Grove',
#   'Belmont Road',
#   'Bouverie Mews',
#   'Belgrave Square',
#   'Blithfield Street',
#   'Bensbury Close',
#   'Baltic Close',
#   'Burghill Road',
#   'Buttesland Street',
#   'Burr Close',
#   'Burges Road',
#   'Bridgewater Square',
#   'Bushey Down',
#   'Brecon Green',
#   'Bernal Close',
#   'Burrage Road',
#   'Birkbeck Place',
#   'Boardman Avenue',
#   'Blagdon Road',
#   'Bellasis Avenue',
#   'Brocklesby Road',
#   'Blacktree Mews',
#   'Bolton Close',
#   'Bolingbroke Road',
#   'Bedford Close',
#   'Broadhurst Gardens',
#   'Barchester Close',
#   'Bell Gardens',
#   'Broxbourne Road',
#   'Bentfield Gardens',
#   'Bedser Close',
#   'Bromhedge',
#   'Ballina Street',
#   'Briscoe Close',
#   'Bulstrode Place',
#   'Brunswick Park Road',
#   'Burford Road',
#   'Barston Road',
#   'Braemar Avenue',
#   'Bargery Road',
#   'Burleigh Gardens',
#   'Browning Road',
#   'Brent Green',
#   'Botts Mews',
#   'Beckwith Road',
#   'Bigbury Close',
#   'Bruton Lane',
#   'Burder Close',
#   'Bennington Road',
#   'Belfort Road',
#   'Brookfield Park',
#   'Bailey Place',
#   'Beverston Mews',
#   'Burnbury Road',
#   'Bugsbys Way',
#   'Broadview Road',
#   'Blendworth Way',
#   'Burlington Place',
#   'Bliss Crescent',
#   'Beatrice Avenue',
#   'Bridges Road',
#   'Birkdale Road',
#   'Bury Street',
#   'Bertram Road',
#   'Broadwater Road',
#   'Beechwood Grove',
#   'Bramwell Mews',
#   'Boxley Street',
#   'Brabourne Close',
#   'Banning Street',
#   'Beckway Street',
#   'Beacon Hill',
#   'Belmont Park Close',
#   'Bulinga Street',
#   'Becket Road',
#   'Belmont Park',
#   'Berens Road',
#   'Bramford Road',
#   'Batchelor Street',
#   'Bush Lane',
#   'Barrow Hill Road',
#   'Berryfield Close',
#   'Birse Crescent',
#   'Balcombe Street',
#   'Benthal Road',
#   'Brockwell Park Gardens',
#   'Brinklow Crescent',
#   'Brentfield Road',
#   'Brighton Avenue',
#   'Blaker Court',
#   'Bermondsey Square',
#   'Braxfield Road',
#   'Broomgrove Road',
#   'Brettell Street',
#   'Beauval Road',
#   'Bush Hill Road',
#   'Burnside Close',
#   'Bourdon Street',
#   'Becondale Road',
#   'Battersea Park Road',
#   'Blairderry Road',
#   'Bramcote Grove',
#   'Bethune Avenue',
#   'Brockley Road',
#   'Bunyan Road',
#   'Bourne Gardens',
#   'Broxholm Road',
#   'Birkbeck Road',
#   'Brunswick Square',
#   'Beverley Road',
#   'Boreham Road',
#   'Boscombe Gardens',
#   'Battersea Church Road',
#   'Berwyn Road',
#   'Bushmoor Crescent',
#   'Brockley Grove',
#   'Brechin Place',
#   'Blann Close',
#   'Barnwell Road',
#   'Blackheath Park',
#   'Bryant Street',
#   'Belvedere Square',
#   'Blackshaw Road',
#   'Brooklyn Grove',
#   'Bruton Way',
#   'Beccles Street',
#   'Bramshill Gardens',
#   'Beloe Close',
#   'Brunswick Mews',
#   'Blanmerle Road',
#   'Blenheim Rise',
#   'Bramhope Lane',
#   'Belsize Mews',
#   'Bianca Road',
#   'Broxbourne Avenue',
#   'Bell Drive',
#   'Batten Close',
#   'Beech Close',
#   'Bishop Street',
#   'Blake Close',
#   'Belton Way',
#   'Brooklands Park',
#   'Black Friars Lane',
#   'Brondesbury Villas',
#   'Beardsley Way',
#   'Brookland Garth',
#   'Bourneside Gardens',
#   'Burton Place',
#   'Birchington Court',
#   'Broxwood Way',
#   'Borough Road',
#   'Bolden Street',
#   'Burne Street',
#   'Badminton Road',
#   'Brookfield Avenue',
#   'Billing Road',
#   'Brunswick Quay',
#   'Bramall Close',
#   'Burston Road',
#   'Bellwood Road',
#   'Birdhurst Road',
#   'Brisbane Road',
#   'Baird Close',
#   'Buckingham Place',
#   'Baron Walk',
#   'Bellot Gardens',
#   'Brett Crescent',
#   'Bridgeland Road',
#   'Bowyer Street',
#   'Burlington Arcade',
#   'Brecon Court',
#   'Blakeney Close',
#   'Broomfield Cottages',
#   'Brixton Road',
#   'Beechwood Close',
#   'Bruton Place',
#   'Belton Road',
#   'Bravington Place',
#   'Bourke Close',
#   'Boutique Hall',
#   'Bedford Road',
#   'Braid Avenue',
#   'Boat Lifter Way',
#   'Balmuir Gardens',
#   'Balmes Road',
#   'Beacon Road',
#   'Blenheim Close',
#   'Bridge Villas',
#   'Bowyer Court',
#   'Burton Road',
#   'Beech Court',
#   'Bailey Cottages',
#   'Bradwell Close',
#   'Bowland Road',
#   'Bernard Ashley Drive',
#   'Blackheath Village',
#   'Baird Gardens',
#   'Brill Place',
#   'Bourne Road',
#   'Barnsbury Terrace',
#   'Broomfield Avenue',
#   'Branch Street',
#   'Bateson Street',
#   'Bletsoe Walk',
#   'Babington Road',
#   'Bartle Avenue',
#   'Billson Street',
#   'Boscombe Avenue',
#   'Ballance Road',
#   'Bowen Drive',
#   'Battersea High Street',
#   'Bishops Bridge Road',
#   'Bycroft Street',
#   'Byam Street',
#   'Berrymead Gardens',
#   'Broadhead Strand',
#   'Brooksby Street',
#   'Beech Tree Glade',
#   'Burley Road',
#   'Brightfield Road',
#   'Bowman Mews',
#   'Bateman Road',
#   'Ballingdon Road',
#   'Bonchurch Road',
#   'Bush Grove',
#   'Bright Street',
#   'Bowater Place',
#   'Brampton Grove',
#   'Baseing Close',
#   'Bridge Approach',
#   'Bronhill Terrace',
#   'Bennett Grove',
#   'Bramah Green',
#   'Bourn Avenue',
#   'Butler Road',
#   'Bellina Mews',
#   'Blondel Street',
#   'Berkley Grove',
#   'Broadway',
#   'Banstead Street',
#   'Byards Croft',
#   'Bow Lane',
#   'Britannia Row',
#   'Beverley Avenue',
#   'Ballast Quay',
#   'Beacon Gate',
#   'Bow Locks',
#   'Basing Way',
#   'Baylis Road',
#   'Barnes Avenue',
#   'Boundary Street',
#   'Brooksville Avenue',
#   'Bunton Street',
#   'Bucknell Close',
#   'Burford Gardens',
#   'Bowling Green Row',
#   'Buxton Road',
#   'Broomfield Place',
#   'Brackenfield Close',
#   'Barton Street',
#   'Bekesbourne Street',
#   'Brookville Road',
#   'Brompton Park Crescent',
#   'Boyd Road',
#   'Baronet Grove',
#   'Brick Court',
#   'Bateman Street',
#   'Blakenham Road',
#   'Barnsdale Road',
#   'Brookstone Court',
#   'Beaufort Park',
#   'Brookehowse Road',
#   'Brewhouse Lane',
#   'Beaumont Street',
#   'Belmont Parade',
#   'Bayes Close',
#   'Bramdean Crescent',
#   'Braybrooke Gardens',
#   'Buck Street',
#   'Beardell Street',
#   'Beresford Road',
#   'Bolney Gate',
#   'Bracey Mews',
#   'Burrow Walk',
#   'Beck Road',
#   'Beechwood Park',
#   'Boyard Road',
#   'Baronsmede',
#   'Balfour Mews',
#   'Beckton Road',
#   'Balham High Road',
#   'Bowmans Lea',
#   'Burton Bank',
#   'Bignell Road',
#   'Benin Street',
#   'Brenton Street',
#   'Bonville Gardens',
#   'Bridgewood Road',
#   'Bramdean Gardens',
#   'Bramley Close',
#   'Beverley Path',
#   'Bexhill Walk',
#   'Bentons Lane',
#   'Brierley Close',
#   'Belvedere Road',
#   'Bark Place',
#   'Brendon Avenue',
#   'Brewster Road',
#   'Betterton Street',
#   'Blackstock Road',
#   'Brompton Square',
#   'Berridge Mews',
#   'Balfern Grove',
#   'Broome Way',
#   'Bonheur Road',
#   'Bering Square',
#   'Bristol Mews',
#   'Bolingbroke Grove',
#   'Bridge Place',
#   'Brunswick Road',
#   'Bittacy Road',
#   'Bewley Street',
#   'Bourneside Crescent',
#   'Brussels Road',
#   "Baker's Row",
#   'Blackthorne Drive',
#   'Bilsby Grove',
#   'Brockway Close',
#   'Basket Gardens',
#   'Besley Street',
#   'Burnt Ash Hill',
#   'Bushey Road',
#   'Bythorn Street',
#   'Bowerman Avenue',
#   'Brentmead Close',
#   'Burnaby Street',
#   'Beaumont Avenue',
#   'Blenheim Road',
#   'Bluehouse Road',
#   'Broad Walk Lane',
#   'Bisterne Avenue',
#   'Brandram Road',
#   'Baches Street',
#   'Beltran Road',
#   'Bennett Street',
#   'Bloomfield Terrace',
#   'Belle Vue Estate',
#   'Brewer Street',
#   'Bellot Street',
#   'Bowater Road',
#   'Benwick Close',
#   'Barville Close',
#   'Balfour Street',
#   'Brook Gardens',
#   'Berryhill Gardens',
#   'Bostall Heath',
#   'Brenda Road',
#   'Bergen Square',
#   'Berners Place',
#   'Brook Meadow',
#   'Birchdale Road',
#   'Bessie Lansbury Close',
#   'Bendish Road',
#   'Beeches Close',
#   'Beardsfield',
#   'Bullards Place',
#   'Bridgewood Close',
#   'Bassant Road',
#   'Bosgrove',
#   'Byron Road',
#   'Barnet Way',
#   'Basire Street',
#   'Basing Court',
#   'Berry Way',
#   'Burnhill Close',
#   'Bay Court',
#   'Beeston Place',
#   'Brodlove Lane',
#   'Bakers Hill',
#   'Brenthouse Road',
#   'Brampton Park Road',
#   'Burroughs Parade',
#   'Bensley Close',
#   'Botha Road',
#   'Briarwood Close',
#   'Bull Lane',
#   'Broad Walk',
#   'Bransdale Close',
#   'Becket Avenue',
#   'Bow Road',
#   'Brook Close',
#   'Back Hill',
#   'Brickwood Close',
#   'Brougham Road',
#   'Bassingham Road',
#   'Bryanston Street',
#   'Bruno Place',
#   "Brooksby's Walk",
#   'Brune Street',
#   'Bank Buildings',
#   'Brewhouse Road',
#   'Bainbridge Street',
#   'Bleak Hill Lane',
#   'Bathurst Street',
#   'Bewlys Road',
#   'Browning Street',
#   'Bounds Green Road',
#   'Broadmead',
#   'Benson Road',
#   'Brixham Street',
#   'Bronti Close',
#   'Broadfields Avenue',
#   'Beresford Terrace',
#   'Beechmount Avenue',
#   'Belsize Crescent',
#   'Brockley Gardens',
#   'Brook Road',
#   'Bute Street',
#   'Barnard Close',
#   'Boston Road',
#   'Byton Road',
#   'Beechwood Mews',
#   'Benhurst Lane',
#   'Binns Road',
#   'Burness Close',
#   'Bedford Row',
#   'Brentside Close',
#   'Bush Cottages',
#   'Blissett Street',
#   'Becmead Avenue',
#   'Butterfly Walk',
#   'Buttermere Walk',
#   'Benham Close',
#   'Basil Street',
#   'Bloomfield Place',
#   'Bolton Gardens Mews',
#   'Biggerstaff Street',
#   'Burlington Parade',
#   'Binns Terrace',
#   'Berry Street',
#   'Belitha Villas',
#   'Buckters Rents',
#   'Bloom Park Road',
#   'Blackfords Path',
#   'Blomfield Road',
#   'Battledean Road',
#   'Bradymead',
#   'Bunning Way',
#   'Blythe Mews',
#   'Burton Street',
#   'Brooks Mews',
#   'Bramfield Road',
#   'Bowmead',
#   'Bowdon Road',
#   'Bridewell Place',
#   'Burnthwaite Road',
#   'Bullivant Street',
#   'Bloomhall Road',
#   'Birkdale Close',
#   'Barons Court Road',
#   'Baildon Street',
#   'Baldwins Gardens',
#   'Batman Close',
#   'Berners Road',
#   'Bingley Road',
#   'Bourne Estate',
#   'Butler Street',
#   'Bramley Court',
#   'Bignold Road',
#   'Boyd Street',
#   'Berthons Gardens',
#   'Bromley High Street',
#   'Brompton Cottages',
#   'Brants Walk',
#   'Bromar Road',
#   'Bisham Gardens',
#   'Bullen Street',
#   'Brook Park Close',
#   'Bev Callender Close',
#   'Bodley Manor Way',
#   'Baring Road',
#   'Broomsleigh Street',
#   'Burlington Road',
#   'Buxted Road',
#   'Bangalore Street',
#   'Beehive Close',
#   'Borthwick Mews',
#   'Bryanston Mews East',
#   'Burrage Place',
#   'Balnacraig Avenue',
#   'Bywater Street',
#   'Burwell Close',
#   'Beaconsfield Close',
#   'Barnabas Road',
#   'Brooklands Avenue',
#   'Batson Street',
#   'Bishop Way',
#   'Brecon Road',
#   'Borthwick Road',
#   'Beatty Street',
#   'Blondin Street',
#   'Birchen Grove',
#   'Burstow Road',
#   'Baltic Place',
#   'Bloom Grove',
#   'Brady Street',
#   'Belmont Mews',
#   'Besant Road',
#   'Blackheath Rise',
#   'Barlow Street',
#   'Besson Street',
#   'Barford Street',
#   'Bow Street',
#   'Brockham Drive',
#   'Brabazon Street',
#   'Bancroft Road',
#   'Balchier Road',
#   'Booth Close',
#   'Belvedere Grove',
#   'Bovingdon Close',
#   'Blaney Crescent',
#   'Bledlow Close',
#   'Barham Road',
#   'Brabant Road',
#   'Boscobel Street',
#   'Braeside Road',
#   'Bradstock Road',
#   'Barnard Grove',
#   'Bonneville Gardens',
#   'Baynes Street',
#   'Blythwood Road',
#   'Bridge Parade',
#   'Britannia Street',
#   'Bridges Mews',
#   'Belford Grove',
#   'Brynmaer Road',
#   'Bethnal Green Road',
#   'Beaumont Gardens',
#   'Bevington Street',
#   'Barnet Lane',
#   'Buxton Drive',
#   'Bickley Street',
#   'Belmont Park Road',
#   'Belfast Road',
#   'Balmoral Gardens',
#   'Besant Way',
#   'Burnett Close',
#   'Buckfast Street',
#   'Bridgeway Street',
#   'Barnard Mews',
#   'Bracken Close',
#   'Birkwood Close',
#   'Bentworth Road',
#   'Bellestaines Pleasaunce',
#   'Beattock Rise',
#   'Badsworth Road',
#   'Broseley Grove',
#   'Batty Street',
#   'Berger Road',
#   'Burley Close',
#   'Bredhurst Close',
#   'Basing Street',
#   'Baring Close',
#   'Beckenham Hill Road',
#   'Brighton Terrace',
#   'Brad Street',
#   'Brooks Avenue',
#   'Burgh Street',
#   'Belson Road',
#   'Bury Street West',
#   'Bowfell Road',
#   'Bourne Place',
#   'Burdett Close',
#   'Berkeley Gardens',
#   'Bracken Gardens',
#   'Bracewell Road',
#   'Balaclava Road',
#   'Belmont Terrace',
#   'Ballantine Street',
#   'Blackstock Mews',
#   'Broadlands Avenue',
#   'Briarfield Avenue',
#   'Bradshaws Close',
#   'Branksea Street',
#   'Bertrand Way',
#   'Birkbeck Grove',
#   'Brim Hill',
#   'Brookfield Crescent',
#   'Border Road',
#   'Brook Lane',
#   'Baron Street',
#   'Bowmore Walk',
#   'Brookscroft Road',
#   'Beckway Road',
#   'Bickerton Road',
#   'Broadwall',
#   'Birley Road',
#   'Bolton Street',
#   'Byng Street',
#   'Broadley Street',
#   'Begonia Close',
#   'Benbow Street',
#   'Bishop Wilfred Wood Close',
#   'Bayham Street',
#   'Brookdale',
#   'Britton Street',
#   "Bream's Buildings",
#   'Brunner Road',
#   'Beardow Grove',
#   'Beaufort Drive',
#   'Burke Street',
#   'Burlington Gardens',
#   'Brownswell Road',
#   'Burnbrae Close',
#   'Bury Place',
#   'Boultwood Road',
#   'Barn Close',
#   'Brudenell Road',
#   'Brandon Street',
#   'Barn Field',
#   'Bradbourne Street',
#   'Bollo Lane',
#   'Boltmore Close',
#   'Bull Road',
#   'Bell Lane',
#   'Brushfield Street',
#   'Beaumont Mews',
#   'Bedale Street',
#   'Bates Crescent',
#   'Burwood Place',
#   'Byfield Close',
#   'Badlis Road',
#   'Blackheath Hill',
#   'Bronsart Road',
#   'Berrymans Lane',
#   'Birkbeck Avenue',
#   'Blackdown Terrace',
#   'Beckenham Gardens',
#   'Beaconsfield Terrace Road',
#   'Benson Avenue',
#   'Ballogie Avenue',
#   'Beacontree Road',
#   'Bradwell Mews',
#   'Battenburg Walk',
#   'Boxall Road',
#   'Blackhorse Lane',
#   'Bounces Road',
#   'Burgoyne Road',
#   'Broadway Mews',
#   'Bridge Close',
#   'Barnsbury Square',
#   'Boscombe Road',
#   'Basswood Close',
#   'Barson Close',
#   'Blessington Road',
#   'Braydon Road',
#   'Belvedere Buildings',
#   'Bevin Square',
#   'Briggeford Close',
#   'Brunel Close',
#   'Bridge Road',
#   'Barnfield Gardens',
#   'Bartholomew Square',
#   'Bathurst Avenue',
#   'Burrell Street',
#   'Bermondsey Wall East',
#   'Bishops Close',
#   'Broomfield Street',
#   'Balfour Avenue',
#   'Bramblebury Road',
#   'Brookland Rise',
#   'Benares Road',
#   'Basing Hill',
#   'Bosworth Road',
#   'Belsham Street',
#   'Barrett Road',
#   'Bonsor Street',
#   'Brassie Avenue',
#   'Beale Close',
#   'Brycedale Crescent',
#   'Birch Avenue',
#   'Beadon Road',
#   'Berkeley Court',
#   'Bedford Avenue',
#   'Burntwood Grange Road',
#   'Buckden Close',
#   'Boundfield Road',
#   'Brookview Road',
#   'Billing Place',
#   'Bittacy Close',
#   'Borland Road',
#   'Braemar Road',
#   'Bassett Road',
#   'Brighton Grove',
#   'Bushwood',
#   'Bayham Place',
#   'Betstyle Road',
#   'Bow Churchyard',
#   'Burwell Walk',
#   'Besant Close',
#   'Boscobel Place',
#   'Bampton Road',
#   'Belgrave Gardens',
#   'Berkshire Gardens',
#   'Broadwalk',
#   'Branch Road',
#   'Becklow Gardens',
#   'Briaris Close',
#   'Buckleigh Avenue',
#   'Baptist Gardens',
#   'Beech Road',
#   'Brook Crescent',
#   'Bristol Park Road',
#   'Beechdale Road',
#   'Brookhill Road',
#   'Battersea Bridge Road',
#   'Butlers Drive',
#   'Bow Common Lane',
#   'Blagrove Road',
#   'Balchen Road',
#   'Blakesley Avenue',
#   'Barfreston Way',
#   'Bressenden Place',
#   'Butterfield Close',
#   'Bravington Road',
#   'Burntwood Close',
#   'Birchin Lane',
#   'Burnham Way',
#   'Berners Mews',
#   'Bride Street',
#   'Bird In Hand Passage',
#   'Broadhinton Road',
#   'Bolingbroke Walk',
#   'Brampton Close',
#   'Berrymede Road',
#   'Bowyer Close',
#   'Buckland Road',
#   'Bedford Hill',
#   'Belgrave Mews South',
#   'Bird Street',
#   'Bewick Street',
#   'Byland Close',
#   ...],
#  ['Chartham Grove',
#   'Cheyne Row',
#   'Clack Street',
#   'Cranwell Close',
#   'Choumert Square',
#   'Carlos Place',
#   'Coniston Gardens',
#   'Cowper Road',
#   'Chippendale Street',
#   'Coolhurst Road',
#   'Cardigan Walk',
#   'Cokers Lane',
#   'Cheverton Road',
#   'Corlett Street',
#   'Chevet Street',
#   'Capstan Square',
#   'Chichester Way',
#   'Clare Lane',
#   'Castle Hill Parade',
#   'Cotts Close',
#   'Covington Way',
#   'Carlisle Walk',
#   'Coulter Road',
#   'Courthill Road',
#   'Clapham Road Estate',
#   'Cumberland Road',
#   'Chelsea Harbour',
#   'Cumberland Terrace Mews',
#   'Chadwell Street',
#   'Corfield Road',
#   'Camille Close',
#   'Corris Green',
#   'Charles Square',
#   'Cedar Court',
#   'Crane Grove',
#   'Courtney Road',
#   'Canonbie Road',
#   'Clock Tower Place',
#   'Caney Mews',
#   'Claribel Road',
#   'Christchurch Passage',
#   'Chiswick Road',
#   'Colmore Mews',
#   'Caradon Close',
#   'Campden Hill Place',
#   'Congress Road',
#   'Carteret Way',
#   'Chelmsford Road',
#   'Cliveden Road',
#   'Clandon Street',
#   'Clifton Avenue',
#   'Clothworkers Road',
#   'Collards Almshouses',
#   'Cuthbert Road',
#   'Collings Close',
#   'Coverley Close',
#   'Chase Way',
#   'Cranmer Avenue',
#   'Campbell Walk',
#   'Church Entry',
#   'Croftdown Road',
#   'Chiswick Lane',
#   'Castlewood Road',
#   'Craignair Road',
#   'Crockham Way',
#   'Campen Close',
#   'Cranfield Drive',
#   'Claremont Way',
#   "Clifford's Inn Passage",
#   'Crown Office Row',
#   'Cinnamon Street',
#   'County Road',
#   'Chicheley Street',
#   'Cowthorpe Road',
#   'Colepits Wood Road',
#   'Chesley Gardens',
#   'Chadd Green',
#   'Copleston Road',
#   'Church Court',
#   'Clifton Place',
#   'Carmalt Gardens',
#   'Cobbold Mews',
#   'Crown Court',
#   'Culmington Parade',
#   'Courtrai Road',
#   'Claygate Road',
#   'Cromwell Close',
#   'Charlotte Street',
#   'Charlwood Terrace',
#   'Codrington Mews',
#   'Camilla Road',
#   'Copthall Gardens',
#   'Chatham Street',
#   'Colchester Road',
#   'Crowfoot Close',
#   'Clarkson Row',
#   'Cambrian Green',
#   'Cheltenham Place',
#   'Conlan Street',
#   'Cranston Estate',
#   'Crystal Terrace',
#   'Crawthew Grove',
#   'Coburg Road',
#   'Comyn Road',
#   'Catherine Wheel Yard',
#   'Coach Yard Mews',
#   'Croft Road',
#   'Chaseley Drive',
#   'Corrance Road',
#   'Cambrian Road',
#   'Coombs Street',
#   'Claire Place',
#   'Churton Place',
#   'Crescent Lane',
#   'Campden Grove',
#   'Chelsea Park Gardens',
#   'Couthurst Road',
#   'Chatsworth Avenue',
#   'Crutched Friars',
#   'Copwood Close',
#   'Crace Street',
#   'Castle Place',
#   'Copperfield Road',
#   'Crothall Close',
#   'Carberry Road',
#   'Chatto Road',
#   'Commodore Street',
#   'Cypress Gardens',
#   'Campana Road',
#   'Connaught Mews',
#   'College East',
#   'Court Lane',
#   'Carleton Road',
#   'Childs Lane',
#   'Clutton Street',
#   'Coleridge Close',
#   'Church Passage',
#   'Canterbury Place',
#   'Claughton Road',
#   'Chargrove Close',
#   'Christchurch Road',
#   'Cold Blow Lane',
#   'Caroline Walk',
#   'Chesterton Square',
#   'Calcott Walk',
#   'Coney Way',
#   'Canute Gardens',
#   'Copley Close',
#   'Coldharbour Crest',
#   'Cullum Street',
#   'College Mews',
#   'Chisenhale Road',
#   'Coates Avenue',
#   'Castle Close',
#   'Canada Square',
#   'Conolly Road',
#   'Culford Gardens',
#   'Crowthorne Close',
#   'Canning Passage',
#   'Chillingworth Road',
#   'Charnock Road',
#   'Cornwallis Grove',
#   'Clonmel Road',
#   'Cephas Street',
#   'Champion Park',
#   'Crofts Lane',
#   'Charlotte Mews',
#   'Chamberlain Cottages',
#   'Cordwainers Walk',
#   'Carnanton Road',
#   'Coldharbour Lane',
#   'Carey Lane',
#   'Caroline Close',
#   'Charles Square Estate',
#   'Cranley Road',
#   'Coupland Place',
#   'Combedale Road',
#   'Cambridge Avenue',
#   'Cyclops Mews',
#   'Christchurch Terrace',
#   'Cuthbert Street',
#   'Chipley Street',
#   'Coopersale Road',
#   'Curtain Road',
#   'Cynthia Street',
#   'Coppice Way',
#   'Crumpsall Street',
#   'Castellain Road',
#   'Camden Mews',
#   'Charlesworth Place',
#   'Chartley Avenue',
#   'Chalfont Way',
#   'Crossway Parade',
#   'Culmore Road',
#   'Coleridge Lane',
#   'Coxson Way',
#   'Chatham Close',
#   'Clarkson Street',
#   'Chobham Road',
#   'Caithness Road',
#   'Chamber Street',
#   'Chagford Street',
#   'Cotswold Street',
#   'Callcott Road',
#   'Chelsea Gardens',
#   'Chiswick Lane South',
#   'Childebert Road',
#   'Churchway',
#   'Cromwell Road',
#   'Curtis Drive',
#   'Chetwynd Road',
#   'Church Crescent',
#   'Corsham Street',
#   'Craigholm',
#   'Cleve Road',
#   'Connaught Road',
#   'Colfe Road',
#   'Castlewood Drive',
#   'Charlow Close',
#   'Cedric Road',
#   'Coulson Street',
#   'Coralline Walk',
#   'Cossall Walk',
#   'Campshill Road',
#   'Coal Wharf Road',
#   'Cherington Road',
#   'Camborne Avenue',
#   'Coombe Road',
#   'Cliveden Close',
#   'Cargreen Road',
#   'Coppelia Road',
#   'Campden Terrace',
#   'Cathay Street',
#   'Cotton Street',
#   'Chapel House Street',
#   'Camberwell Green',
#   'Chesham Crescent',
#   'Central Square',
#   'Clevedon Close',
#   'Coval Passage',
#   'Chequer Street',
#   'Crucifix Lane',
#   'Cromford Path',
#   'Cambridge Green',
#   'Cartwright Street',
#   'Carbery Avenue',
#   'Court Lane Gardens',
#   'Cooks Road',
#   'Cowley Lane',
#   'Clover Close',
#   'Chettle Close',
#   'Cadell Close',
#   'Calico Row',
#   'Clandon Terrace',
#   'Chicksand Street',
#   'Colosseum Terrace',
#   'Clarendon Street',
#   'Coach House Lane',
#   'Courtfield Gardens',
#   'Cowper Avenue',
#   'Carters Hill Close',
#   'Copthall Avenue',
#   'Cale Street',
#   'Clarence Mews',
#   'Cormorant Road',
#   'Craven Avenue',
#   'Congreve Road',
#   'Cassiobury Road',
#   'Cutcombe Road',
#   'Champion Crescent',
#   'Clarissa Street',
#   'Church Green',
#   'County Street',
#   'Conyer Street',
#   'Cromford Road',
#   'Cascade Avenue',
#   'Chenappa Close',
#   'Callow Street',
#   'Canham Road',
#   'Cursitor Street',
#   'Custom House Reach',
#   'Chilham Road',
#   'Chaucer Road',
#   'Colva Walk',
#   'Carteret Street',
#   'Cromwell Grove',
#   'Catherine Street',
#   'Chapel Road',
#   'Charterhouse Mews',
#   'Caversham Avenue',
#   'Colwick Close',
#   'Constantine Road',
#   'Cleveland Road',
#   'Celandine Way',
#   'Croydon Road',
#   'Crane Avenue',
#   'Cudham Street',
#   'Cranmore Way',
#   'Crofts Street',
#   'Cheltenham Gardens',
#   'College Yard',
#   'Cambalt Road',
#   'Crofton Terrace',
#   'Cardigan Street',
#   'Coopers Lane',
#   'Crowther Road',
#   'Chaucer Way',
#   'Christchurch Way',
#   'Church Hill Road',
#   'Cornish Grove',
#   'Cavendish Road',
#   'Corney Road',
#   'Connaught Gardens',
#   'Central Way',
#   'Charlton Road',
#   'Coin Street',
#   'Chamberlayne Road',
#   'Colin Park Road',
#   'Commonwealth Way',
#   'Colet Gardens',
#   'Codicote Terrace',
#   'Crebor Street',
#   'Carr Road',
#   'Caroline Terrace',
#   'Chatsfield Place',
#   'Chudleigh Street',
#   'Cahir Street',
#   'Commercial Road',
#   'Clive Avenue',
#   'College Green',
#   'Cricket Row',
#   'Claudia Jones Way',
#   'Cheyne Path',
#   'Cresswell Gardens',
#   'Cheltenham Terrace',
#   'Churston Avenue',
#   'Clearwell Drive',
#   'Chesney Street',
#   'Chaseville Park Road',
#   'Chardwell Close',
#   'Charlton Park Lane',
#   'Chudleigh Road',
#   'Cloudesdale Road',
#   'Clarendon Terrace',
#   'Crossley Street',
#   'Cowan Close',
#   'Copleston Mews',
#   'Cumberland Crescent',
#   'Cutler Street',
#   'Chelmsford Close',
#   'Comber Close',
#   'Crofton Road',
#   'Chester Close',
#   'Cathcart Hill',
#   'Calderwood Street',
#   'Charlwood Road',
#   'Crowland Road',
#   'Carthew Villas',
#   'Courcy Road',
#   'Clorane Gardens',
#   'Claude Road',
#   'Cherrydown Avenue',
#   'Cobham Road',
#   'Capel Close',
#   'Cottesloe Mews',
#   'Castle Avenue',
#   'Cardinal Place',
#   'Conybeare',
#   'Cottenham Road',
#   'Crossmead',
#   'Caroline Place',
#   'Cressfield Close',
#   'Cavendish Parade',
#   'Clermont Road',
#   'Clayton Mews',
#   'Campsbourne Road',
#   'Courtleigh Gardens',
#   'Coney Burrows',
#   'Clarkes Mews',
#   'Church Gardens',
#   'Collingtree Road',
#   'Colville Houses',
#   'Cowley Street',
#   'Crutchley Road',
#   'Cedars Road',
#   'Champion Grove',
#   'Centre Avenue',
#   'Cherry Tree Walk',
#   'Crown Woods Way',
#   'Clennam Street',
#   'Crispian Close',
#   'Candler Street',
#   'Conant Mews',
#   'Crescent Gardens',
#   'Chadwick Way',
#   'Cobham Close',
#   'Cullingworth Road',
#   'Clovelly Gardens',
#   'Chesnut Grove',
#   'Cope Street',
#   'Condray Place',
#   'Clarewood Walk',
#   'Caravel Close',
#   'Cardrew Close',
#   'Church Hyde',
#   'Cranley Parade',
#   'Clanfield Way',
#   'Cold Harbour',
#   'Carlton House Terrace',
#   'Corsley Way',
#   'Carlton Road',
#   'Cromer Villas Road',
#   'Cumberland Avenue',
#   'Coleridge Walk',
#   'Catton Street',
#   'Carlisle Road',
#   'Chase Gardens',
#   'Charlmont Road',
#   'Carlyle Mews',
#   'Carver Close',
#   'Chandos Road',
#   'Coventry Close',
#   'Canning Cross',
#   'Colebert Avenue',
#   'Cotall Street',
#   'Canal Way',
#   'Chatfield Road',
#   'Calidore Close',
#   'Castelnau',
#   'Crewdson Road',
#   'Chandos Place',
#   'Colebrooke Drive',
#   'Clare Mews',
#   'Campshill Place',
#   'Christophers Mews',
#   'Claremont Road',
#   'Clapham Common South Side',
#   'Coval Gardens',
#   'Cock Lane',
#   'Clifton Street',
#   'Conduit Street',
#   'Crieff Road',
#   'Chandlers Mews',
#   'Clement Close',
#   'Clyston Street',
#   'Central Circus',
#   'Chiswick Pier',
#   'Caedmon Road',
#   'Colebrook Close',
#   'Cranfield Row',
#   'Colina Road',
#   'Colnbrook Street',
#   'Celestial Gardens',
#   'Church Walk',
#   'Clementina Road',
#   'Cranwood Street',
#   'Cannon Road',
#   'Charles Flemwell Mews',
#   'College Lane',
#   'Cundy Street',
#   'Compton Avenue',
#   'Childs Street',
#   'Carpenters Mews',
#   'Chester Row',
#   'Chalcot Gardens',
# ...
#   'Willesden Lane',
#   'Wakefield Street',
#   'Whitcher Close',
#   'Woodleigh',
#   'West Close',
#   'Willis Street',
#   'Wadhurst Close',
#   'Woodmere',
#   'Woodcote Place',
#   'Waldo Close',
#   'West Heath Avenue',
#   'Westcote Road',
#   'Watersmeet Way',
#   'Woodfield Close',
#   'Worlds End Estate',
#   'Walter Terrace',
#   'Wheeler Gardens',
#   'Woodstock Terrace',
#   'West Smithfield',
#   'Wellesley Avenue',
#   'Westbourne Street',
#   'Woodman Lane',
#   'Welford Close',
#   'Webb Road',
#   'Wyndham Mews',
#   'Westfields Avenue',
#   'West House Close',
#   'Westbourne Drive',
#   'Worsopp Drive',
#   'Wardo Avenue',
#   'Wishart Road',
#   'Welshside Walk',
#   'White City Road',
#   'Woodhill',
#   'Walsingham Road',
#   'Waters Place',
#   'Wrigley Close',
#   'West Halkin Street',
#   'Wincrofts Drive',
#   'Winchfield Road',
#   'Waverton Road',
#   'Wheatfields',
#   'Walpole Street',
#   'Watermeadow Lane',
#   'Willow Tree Close',
#   'Woolacombe Road',
#   'Wellstead Avenue',
#   'Winders Road',
#   'White Lyon Court',
#   'Waynflete Square',
#   'Waltham Park Way',
#   'Will Crooks Gardens',
#   'Winstanley Road',
#   'Woodchurch Road',
#   'Weiss Road',
#   'Wood Lane',
#   'Worth Grove',
#   'Withers Mead',
#   'Woodcroft Avenue',
#   'Wearside Road',
#   'Whistler Mews',
#   'Wayfield Link',
#   'Wilton Way',
#   'Wyborne Way',
#   'Wrampling Place',
#   'Westland Place',
#   'Wilmer Way',
#   'Ware Point Drive',
#   'Westbeech Road',
#   'Walnut Gardens',
#   'Whiteley Road',
#   'Waterhall Close',
#   'Wilfred Owen Close',
#   'Wormholt Road',
#   'West Side Common',
#   'Windsor Way',
#   'Watermill Way',
#   'Wolseley Road',
#   'Winn Road',
#   'Windsor Wharf',
#   'Walberswick Street',
#   'Whatley Avenue',
#   'Wilshaw Street',
#   'Walmer Terrace',
#   'William Street',
#   'Whitcher Place',
#   'Welford Place',
#   'Woolmore Street',
#   'Watling Court',
#   'Watney Road',
#   'Wessex Avenue',
#   'Westerfield Road',
#   'Wellside Gardens',
#   'Whistlers Avenue',
#   'Worlds End Lane',
#   'Westbridge Road',
#   'Wavertree Road',
#   'Wigram Road',
#   'Walham Green Court',
#   'Whewell Road',
#   'Wolseley Gardens',
#   'Wimbourne Street',
#   'West Hill Park',
#   'Woolstaplers Way',
#   'Wroxham Gardens',
#   'Waltheof Gardens',
#   'Well Hall Parade',
#   'Wellesley Road',
#   'Western Avenue',
#   'Woodland Crescent',
#   'Westcroft Close',
#   'Woodger Road',
#   'Woodcroft Mews',
#   'Whitfield Place',
#   'Wyldfield Gardens',
#   'Wapping High Street',
#   'Waterfield Cottages',
#   'Wricklemarsh Road',
#   'Waller Road',
#   'Wills Grove',
#   'Westport Road',
#   'Windfield Close',
#   'Westcott Close',
#   'Windmill Drive',
#   'Ward Road',
#   'Waddington Street',
#   'Winnington Close',
#   'Warwick House Street',
#   'White Hart Road',
#   'Windrush Lane',
#   'Wick Square',
#   'Warwick Crescent',
#   'White Post Lane',
#   'Welshpool Street',
#   'Woodville Close',
#   'Winchelsea Road',
#   'Warley Close',
#   'White Orchards',
#   'Wroxham Road',
#   'Woodburn Close',
#   'Wingford Road',
#   'Weymouth Street',
#   'Wroxton Road',
#   'Willow Grove',
#   'Wharfdale Close',
#   'Woking Close',
#   'Whitlock Drive',
#   'Woodrush Close',
#   'Warwick Drive',
#   'Warren Lane',
#   'Winifred Street',
#   'William Square',
#   'Wentworth Gardens',
#   'Westdean Avenue',
#   "World's End Place",
#   'Wanley Road',
#   'Whetstone Road',
#   'Wrights Place',
#   'Wellington Park Estate',
#   'Wat Tyler Road',
#   'Wickers Oake',
#   'Whittle Close',
#   'Wigston Road',
#   'Westcroft Way',
#   'Wigram Square',
#   'Wymond Street',
#   'Warkworth Road',
#   'Woodyates Road',
#   'Warfield Road',
#   'Wakeling Road',
#   'Westview Crescent',
#   'Watling Street',
#   'Williamson Close',
#   'Woodfield Crescent',
#   'Warburton Close',
#   'Wainford Close',
#   'Wheatsheaf Terrace',
#   'Watery Lane',
#   'Winchester Close',
#   'Wauthier Close',
#   'Warley Road',
#   'Warmington Road',
#   'Warren Gardens',
#   'Warham Road',
#   'Weavers Almshouses',
#   'West Ham Park',
#   'Waterfall Terrace',
#   'Wolstonbury',
#   'Worlds End Passage',
#   'Wollaston Close',
#   'Whymark Avenue',
#   'Willis Road',
#   'Windsor Close',
#   'Willowmead Close',
#   'Woodside Grange Road',
#   'Westrow',
#   'Westward Road',
#   'Wayland Avenue',
#   'Waverley Crescent',
#   'Westmorland Close',
#   'Wornington Road',
#   'Wicker Street',
#   'Walt Whitman Close',
#   'Woodleigh Avenue',
#   'Wouldham Road',
#   'Whitworth Road',
#   'Wesley Avenue',
#   'Wyclif Street',
#   'Wallace Road',
#   'Whitecross Street',
#   'Woodside Court',
#   'Waltham Avenue',
#   'Wheatley Street',
#   'Woodlands Close',
#   'Western Gardens',
#   'Woolf Mews',
#   'Wynne Road',
#   'Windmill Street',
#   'Wolsey Road',
#   'Windlesham Grove',
#   'Wandsworth Common',
#   'Wharncliffe Gardens',
#   'Waterloo Place',
#   'Wolsey Close',
#   'Wrigglesworth Street',
#   'Winchester Street',
#   'White Lodge',
#   'Woodbury Road',
#   'Warwick Square Mews',
#   'Weir Road',
#   'Watkinson Road',
#   'Westleigh Avenue',
#   'Waterden Crescent',
#   "Wix's Lane",
#   'Wentworth Street',
#   'Whitehall Road',
#   'Warriner Drive',
#   'Weymouth Villas',
#   'Weydown Close',
#   'Woodbastwick Road',
#   'Waterhouse Close',
#   'Woodstock Crescent',
#   'Wallman Place',
#   'Wincott Street',
#   'William Morris Way',
#   'Wilmington Square',
#   'Weston Park',
#   'Wimborne Drive',
#   'Winterton Place',
#   'Whiteledges',
#   'Winchester Place',
#   'Wilton Estate',
#   'Weech Road',
#   'Woodview Avenue',
#   'Wilton Road',
#   'Wells Terrace',
#   'Wilton Villas',
#   'Whidborne Street',
#   'Wootton Street',
#   'Wynan Road',
#   'Woodside Road',
#   'Wolseley Street',
#   'Wisteria Close',
#   'Wenlock Street',
#   'Westcott Road',
#   'Woodside Park',
#   'Woodford New Road',
#   'Waterman Way',
#   "Wallis's Cottages",
#   'Woolf Close',
#   'Woodville Road',
#   'Wychcombe Studios',
#   'Westmead',
#   'Wordsworth Avenue',
#   'Warfield Yard',
#   'Whitbread Road',
#   'Waterloo Close',
#   'Walton Street',
#   'Wentworth Park',
#   'Wilby Mews',
#   'Wilds Rents',
#   'Welbeck Road',
#   'Waggon Mews',
#   'Warner Street',
#   'Woodstock Mews',
#   'Walter Hurford Parade',
#   'Woodville Gardens',
#   'Wiseman Road',
#   'Worship Street',
#   'Walmer Gardens',
#   'Walton Close',
#   'Winton Avenue',
#   'Wyemead Crescent',
#   'Waldemar Avenue',
#   'Warwick Place',
#   'Wedmore Street',
#   'Woodside Gardens',
#   'Waite Davies Road',
#   'Westhorpe Road',
#   'Woodside',
#   'Witherston Way',
#   'West Lodge Court',
#   'Weybridge Court',
#   'Woodriffe Road',
#   'Woodberry Way',
#   'Whitehall Court',
#   'Waverley Close',
#   'Winsland Mews',
#   'Willow End',
#   'Wren Road',
#   'Waldram Crescent',
#   'Whetstone Close',
#   'Waverley Avenue',
#   'Wyldes Close',
#   'Warwickshire Path',
#   'Winterbrook Road',
#   'Warner Terrace',
#   'Waterfield Gardens',
#   'Warner Road',
#   'Wymering Road',
#   'Windermere Avenue',
#   'Walmer Close',
#   'Wingmore Road',
#   'Well Hall Road',
#   'Woodbrook Road',
#   'Wickford Way',
#   'Wrentham Avenue',
#   'Woodmans Mews',
#   'Woodhatch Close',
#   'Wentworth Road',
#   'Westlake Close',
#   'Westgate Street',
#   'Willoughby Grove',
#   'Wheatley Close',
#   'Western Place',
#   'Winthorpe Road',
#   'Witanhurst Lane',
#   'Walworth Place',
#   'Welland Mews',
#   'Wilcox Road',
#   'Wharf Place',
#   'Westminster Bridge Road',
#   'Waynflete Street',
#   'Westvale Mews',
#   'Winchelsea Close',
#   'Winsor Terrace',
#   'Waterloo Station',
#   'Williamson Street',
#   'Woburn Place',
#   'Warwick Row',
#   'Wilmount Street',
#   'Warlters Road',
#   'West Gardens',
#   'Wickham Road',
#   'Willow Lane',
#   'Willow Walk',
#   'Wooden Bridge Terrace',
#   'Wateridge Close',
#   'Welbeck Way',
#   'Westmoreland Terrace',
#   'William Barefoot Drive',
#   'Wades Place',
#   'Westbourne Terrace',
#   'Woodedge Close',
#   'Wellesley Street',
#   'Woodland Grove',
#   'Winscombe Crescent',
#   'Wetherill Road',
#   'Whitby Gardens',
#   'Wyndham Street',
#   'Wanless Road',
#   'Wyndham Place',
#   'Woodfield Grove',
#   'White House Court',
#   'Wythburn Place',
#   'Wren Path',
#   'Woodlawn Close',
#   'Westmoreland Street',
#   'Winterwell Road',
#   'Waddington Road',
#   'Willow Green',
#   'Winchmore Hill Road',
#   'Watermens Square',
#   'Willowdene',
#   'Whitear Walk',
#   'Windsor Gardens',
#   'Wilton Street',
#   'Wolffram Close',
#   'Wood Close',
#   'Weaver Close',
#   'Water Tower Place',
#   'Wycherley Close',
#   'Whipps Cross Road',
#   'Wemyss Road',
#   'Woodlands Park Road',
#   'Wilna Road',
#   'Wimbledon Park Side',
#   'Winforton Street',
#   'Woodquest Avenue',
#   'Woodcote Avenue',
#   'Woolridge Way',
#   'Worple Street',
#   'Welland Street',
#   'Woolmead Avenue',
#   'Werter Road',
#   'Wharton Street',
#   'Whitley Road',
#   'Woodberry Gardens',
#   'Wayside Grove',
#   'William Morley Close',
#   'Whitmore Close',
#   'Westfield Way',
#   'Woodsome Road',
#   'Wotton Road',
#   'Whittaker Street',
#   'Widecombe Road',
#   'Wilkinson Road',
#   'Worple Road',
#   'Wigmore Place',
#   'Wythfield Road',
#   'Watermint Quay',
#   'Wheatley Gardens',
#   'Wilkinson Street',
#   'Westville Road',
#   'Wattisfield Road',
#   'Wanstead Place',
#   'Waterfall Close',
#   'Woodbourne Close',
#   'William Morris Close',
#   'Wycombe Road',
#   'Whiston Road',
#   'Waldeck Grove',
#   'Williams Road',
#   'Warwall',
#   'Willoughby Lane',
#   'Willow Bridge Road',
#   'Wallingford Avenue',
#   'Wharton Close',
#   'Wadley Road',
#   'Watney Market',
#   'Whitechapel High Street',
#   'Woodbridge Street',
#   'Woodland Way',
#   'Westbere Road',
#   'Walkerscroft Mead',
#   'West Road',
#   'Witney Path',
#   'Wellfit Street',
#   'West Warwick Place',
#   'Wiverton Road',
#   'Woodchester Square',
#   'Watchfield Court',
#   'Wolferton Road',
#   'Westoe Road',
#   'White Horse Road',
#   'Wells Drive',
#   'Wansey Street',
#   'Winterfold Close',
#   'Woodheyes Road',
#   'West Ham Lane',
#   'Wessex Gardens',
#   'Willcott Road',
#   'Woodcombe Crescent',
#   'Water Street',
#   'Wilson Walk',
#   'Winscombe Street',
#   'Warltersville Road',
#   'Wyndham Crescent',
#   'Wensley Close',
#   'Whateley Road',
#   'Windsor Road',
#   'Whitburn Road',
#   'Wise Road',
#   'Warton Road',
#   'Walmer Road',
#   'Wetherby Place',
#   'Wythens Walk',
#   'Werrington Street',
#   'Wooderson Close',
#   'White Conduit Street',
#   'Welbeck Villas',
#   'Windrush Road',
#   'White Lion Street',
#   'Waterloo Terrace',
#   'Woolwich Manor Way',
#   'Well Street',
#   'Webb Estate',
#   'Westbourne Grove Mews',
#   'Wades Grove',
#   'Whitwell Road',
#   'Weymouth Close',
#   'Wendon Street',
#   'Winfrith Road',
#   'Wilmot Close',
#   'Waley Street',
#   'White Bear Place',
#   'Wilman Grove',
#   'Warwick Lane',
#   'Whitefriars Street',
#   'Westway',
#   'Winslow Road',
#   'Wisteria Road',
#   'Woodnook Road',
#   'Wembury Road',
#   'Westcroft Mews',
#   'Woodland Hill',
#   'Wellington Mews',
#   'Whitfield Street',
#   'Waldron Mews',
#   'Whitehall Gardens',
#   'West India House',
#   'Westfield Street',
#   'Walney Walk',
#   'Webber Row',
#   'Wynell Road',
#   'Western Road',
#   'Wigston Close',
#   'Worcester Gardens',
#   'Walfield Avenue',
#   'Windsor Street',
#   'Whales Yard',
#   'Waterfield Close',
#   'Well Walk',
#   'Woodbourne Avenue',
#   'Wildfell Road',
#   'Well Grove',
#   'Woodpecker Road',
#   'Warrington Crescent',
#   'West Garden Place',
#   'Westcott Crescent',
#   'Wavel Mews',
#   'Westcoombe Avenue',
#   'Wyleu Street',
#   'Waverton Street',
#   'Wanborough Drive',
#   'Westwood Avenue',
#   'Waterdale Road',
#   'Walpole Place',
#   'Westmoreland Place',
#   'Warren Way',
#   'West Eaton Place Mews',
#   'Weirdale Avenue',
#   'Witham Road',
#   'Westcroft Square',
#   'Wycombe Place',
#   'Westwood Park',
#   'Woodmans Grove',
#   'Wiltshire Road',
#   'Westerham Avenue',
#   'Wine Office Court',
#   'Whitehaven Street',
#   'Wedderburn Road',
#   'West Hallowes',
#   'Winterstoke Road',
#   'Wimpole Mews',
#   'Wardley Street',
#   'Watford Way',
#   'Whernside Close',
#   'Wharfedale Street',
#   'Weighton Road',
#   'Woolwich Church Street',
#   'Wayside Close',
#   'Watson Mews',
#   "World's End Estate",
#   'Weald Square',
#   'Wingate Road',
#   'Whitefield Close',
#   'Windlass Place',
#   'Walters Road',
#   'Walham Grove',
#   'Wynton Gardens',
#   'Well Close',
#   'Wolftencroft Close',
#   'Windsor Grove',
#   'Wyatt Close',
#   'Wastdale Road',
#   'Watts Close',
#   'Well Lane',
#   'Winchendon Road',
#   'Water Mews',
#   'Wandsworth Common West Side',
#   'Warren Crescent',
#   'Winterstoke Gardens',
#   'Woodville Street',
#   'Wallis Close',
#   'Wellfield Road',
#   'Westchester Drive',
#   'Woodbridge Close',
#   'Webbs Road',
#   'Willan Road',
#   'Woodland Rise',
#   'Wellmeadow Road',
#   'Winstanley Estate',
#   'Woodland Road',
#   'Westbury Arcade',
#   'Willes Road',
#   'Woodside Park Avenue',
#   'Woodmansterne Road',
#   'Wentworth Avenue',
#   'Wall End Road',
#   'Wall Street',
#   'Walsingham Place',
#   'Warren Street',
#   'Westgate Road',
#   'Whitbread Close',
#   'Woodside Lane',
#   'Woodberry Avenue',
#   'Weir Hall Road',
#   'Walnut Tree Close',
#   'Windall Close',
#   'Warbeck Road',
#   'Westbourne Park Road',
#   'Windrush Close',
#   'Walnut Close',
#   'Westbourne Grove',
#   'Widdenham Road',
#   'Wells Street',
#   'Woodbury Park Road',
#   'Weir Hall Avenue',
#   'Wardour Mews',
#   'Wilton Place',
#   'Wavel Place',
#   'Wellington Square',
#   'Winsford Road',
#   'Windsor Terrace',
#   'Winslow Grove',
#   'Wheat Sheaf Close',
#   'Whorlton Road',
#   'Wood Retreat',
#   'Woodside Mews',
#   'West Park',
#   'Westlands Terrace',
#   'White Hart Street',
#   'Winchcomb Gardens',
#   'Westhay Gardens',
#   'Wyatts Lane',
#   'Wigton Place',
#   'Wakeling Street',
#   'Weybourne Street',
#   'Windermere Road',
#   'Wild Hatch',
#   'Wrottesley Road',
#   'West Place',
#   'Widecombe Way',
#   'Wick Lane',
#   'Woodhall Avenue',
#   'Weald Close',
#   'Wren Avenue',
#   'Walton House',
#   'Williams Avenue',
#   'Wood Mead',
#   'Warwick Terrace',
#   'Wynnstay Gardens',
#   'Weigall Road',
#   'Westbourne Park Villas',
#   'Wapping Lane',
#   'Wetherby Mews',
#   'Walden Road',
#   'Wakehurst Road',
#   'Wiltshire Gardens',
#   'White Hart Lane',
#   'Wilton Square',
#   'Wilton Grove',
#   'Wantage Road',
#   'Wickham Mews',
#   'Waterman Street',
#   'Worgan Street',
#   'West Hampstead Mews',
#   'Woodberry Down',
#   'Waldenshaw Road',
#   'Warminster Road',
#   'Wigeon Path',
#   'Woodfield Road',
#   'Wren Close',
#   'Willow Close',
#   'Weltje Road',
#   'Walburgh Street',
#   'Westbridge Close',
#   'Wades Hill',
#   'Waverley Road',
#   'Warden Road',
#   'Woodbury Close',
#   'Ward Hall Court',
#   'Wandsworth Plain',
#   'Walterton Road',
#   'Winston Avenue',
#   'Woodyard Lane',
#   'Wargrave Avenue',
#   'West India Dock Road',
#   'Waghorn Road',
#   'Waldram Park Road',
#   'Wilson Road',
#   'Woolwich New Road',
#   'Wolsey Court',
#   'Woodman Parade',
#   'Woollaston Road',
#   'Wooster Gardens',
#   'Woolstone Road',
#   'Windsock Close',
#   'Wellington Street',
#   'Woodspring Road',
#   'Warrior Square',
#   'Woodstock Grange',
#   'Weyman Road',
#   'Woodgrange Avenue',
#   'Waxlow Road',
#   'Webb Gardens',
#   'Westbourne Avenue',
#   'Well Court',
#   'Woodberry Crescent',
#   'Waldron Road',
#   'Widegate Street',
#   'Wise Lane',
#   'Wildcroft Road',
#   'Whinchat Road',
#   'Wayford Street',
#   'William Margrie Close',
#   'Watson Close',
#   'Westgrove Lane',
#   'Walsham Road',
#   'Wedgwood Way',
#   'Wigmore Street',
#   'Werndee Road',
#   'Waddington Way',
#   'Westminster Road',
#   'Windmill Lane',
#   'Willoughby Street',
#   'Wesley Square',
#   'Wellesley Close',
#   'Westferry Circus',
#   'Whyteville Road',
#   'Wolves Lane',
#   'Westway Close',
#   'Woodthorpe Road',
#   ...],
#  [],
#  ['Yeatman Road',
#   'Yarmouth Crescent',
#   'York Road',
#   'Yarborough Road',
#   'Yeomans Row',
#   'Yewtree Close',
#   'York Hill',
#   'York Street',
#   'Yardley Close',
#   'Yeo Street',
#   'York Terrace East',
#   'Yew Tree Road',
#   'York Gate',
#   'York House Place',
#   'York Rise',
#   'Yukon Road',
#   'Yelverton Road',
#   'York Square',
#   'Yunus Khan Close',
#   'York Way',
#   'Yonge Park',
#   'Yorkshire Close',
#   'York Way Estate',
#   'Yew Tree Close',
#   'Yorkshire Grey Place',
#   'Yoakley Road',
#   'Yeldham Road',
#   'Yeats Close',
#   'Yoke Close',
#   'York Buildings',
#   'Yarrow Crescent',
#   'Young Street',
#   'Yolande Gardens',
#   'York Close',
#   'Yardley Lane',
#   'Yeoman Street',
#   'Yerbury Road',
#   'Young Road',
#   'York Street Chambers',
#   'Yeames Close',
#   'York Terrace West',
#   'Yeldham Villas',
#   'Yorkshire Gardens',
#   'Yuletide Close',
#   'Yarnfield Square',
#   'Yarnton Way',
#   'Yateley Street',
#   'Yew Grove',
#   'York Avenue',
#   'Yorkton Street',
#   'York Mews',
#   'Yewfield Road',
#   'York Parade',
#   'Yeate Street',
#   'Yardley Street',
#   'Yalding Road',
#   'York Grove',
#   'Yeoman Close'],
#  ['Zoffany Street',
#   'Zennor Road',
#   'Zealand Road',
#   'Zoar Street',
#   'Zetland Street',
#   'Zangwill Road',
#   'Zander Court',
#   'Zenoria Street']]

# %%
#flatten the list of lists for london street names
flatten = itertools.chain.from_iterable
list_london_street_names=list(flatten(list_london_street_names))
len(list_london_street_names)
# Out:
# 23337

# %%
#FINAL for the bigger for loop to collect all the elements of the list for letter "Z" because it's a short list
alphabet_letter='z'
list_starting_withZ=[]
for i in range(len(count_pages)):
    if i==0:
        streetmap_url=london_streetmap+alphabet_letter+'/'
        print("page",i," ",streetmap_url)
        map_html_text = requests.get(streetmap_url).text
        soup_map = BeautifulSoup(map_html_text, 'lxml')
        map_ads=soup_map.find_all('td', { "valign": "top" })
        for k in range(len(map_ads)):
            ad = map_ads[k]


            for a in ad.find_all('a', href=True):
                if a['href'].startswith(f'/{alphabet_letter}/'):
                    count_pages.append(a)
                else:
                    list_starting_withZ.append(a.get_text(strip=True))
    else:
        streetmap_url=london_streetmap+alphabet_letter+'/'+str(i+1)
        print("page",i," ",streetmap_url)
        map_html_text = requests.get(streetmap_url).text
        soup_map = BeautifulSoup(map_html_text, 'lxml')
        map_ads=soup_map.find_all('td', { "valign": "top" })

        for k in range(len(map_ads)):
            ad = map_ads[k]


            for a in ad.find_all('a', href=True):
                if a['href'].startswith(f'/{alphabet_letter}/'):
                    count_pages.append(a)
                else:
                    list_starting_withZ.append(a.get_text(strip=True))
list_starting_withZ=set(list_starting_withZ)
len(set(list_starting_withZ))
# Out:
# page 0   http://london.streetmapof.co.uk/z/
# page 1   http://london.streetmapof.co.uk/z/2
# page 2   http://london.streetmapof.co.uk/z/3
# page 3   http://london.streetmapof.co.uk/z/4
# page 4   http://london.streetmapof.co.uk/z/5
# page 5   http://london.streetmapof.co.uk/z/6
# page 6   http://london.streetmapof.co.uk/z/7
# page 7   http://london.streetmapof.co.uk/z/8
# page 8   http://london.streetmapof.co.uk/z/9
# page 9   http://london.streetmapof.co.uk/z/10
# page 10   http://london.streetmapof.co.uk/z/11
# page 11   http://london.streetmapof.co.uk/z/12
# page 12   http://london.streetmapof.co.uk/z/13
# page 13   http://london.streetmapof.co.uk/z/14
# page 14   http://london.streetmapof.co.uk/z/15
# page 15   http://london.streetmapof.co.uk/z/16
# page 16   http://london.streetmapof.co.uk/z/17
# page 17   http://london.streetmapof.co.uk/z/18
# page 18   http://london.streetmapof.co.uk/z/19
# page 19   http://london.streetmapof.co.uk/z/20
# page 20   http://london.streetmapof.co.uk/z/21
# page 21   http://london.streetmapof.co.uk/z/22
# page 22   http://london.streetmapof.co.uk/z/23
# page 23   http://london.streetmapof.co.uk/z/24
# page 24   http://london.streetmapof.co.uk/z/25
# page 25   http://london.streetmapof.co.uk/z/26
# page 26   http://london.streetmapof.co.uk/z/27
# page 27   http://london.streetmapof.co.uk/z/28
# page 28   http://london.streetmapof.co.uk/z/29
# page 29   http://london.streetmapof.co.uk/z/30
# page 30   http://london.streetmapof.co.uk/z/31
# page 31   http://london.streetmapof.co.uk/z/32
# page 32   http://london.streetmapof.co.uk/z/33
# page 33   http://london.streetmapof.co.uk/z/34
# page 34   http://london.streetmapof.co.uk/z/35
# page 35   http://london.streetmapof.co.uk/z/36
# page 36   http://london.streetmapof.co.uk/z/37
# page 37   http://london.streetmapof.co.uk/z/38
# page 38   http://london.streetmapof.co.uk/z/39
# page 39   http://london.streetmapof.co.uk/z/40
# page 40   http://london.streetmapof.co.uk/z/41
# page 41   http://london.streetmapof.co.uk/z/42
# 8

# %%
list_starting_withZ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-faa6d9e9bd2a> in <module>
# ----> 1 list_starting_withZ
#
# NameError: name 'list_starting_withZ' is not defined

# %%
# %%time
#get the results of EPC ratings for all the street names in London starting with Z:
#first create a list of URLs for scraping
list_epc_urls=[]
epc_url='https://find-energy-certificate.digital.communities.gov.uk/find-a-certificate/search-by-street-name-and-town?street_name='
town_url='&town=London'
epc_avg=[]

for street_name in list_starting_withZ:
    url_street_name=street_name.replace(' ','+')
    list_epc_urls.append(epc_url+url_street_name+town_url)

    #iterate through
for url in list_epc_urls:
    
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'lxml')
    epc_ads=soup.find_all('tr', class_ = 'govuk-table__row')
    
    epc_id_ad = 0
    flat_address_final=[]
    epc_rating=[]
    for k in range(len(epc_ads)):
        ad = epc_ads[k]
        flat_address = ad.find_all('a', class_='govuk-link')
  
        if len(flat_address) !=0:
            flat_address_final.append(flat_address[0].get_text(strip=True))
        else: 
            continue

        epc_rating.append(ad.find_all('td', class_='govuk-table__cell')[0].get_text(strip=True))

        epc_id_ad += 1
    if len(epc_rating)!=0:
        epc_avg.append(mode(epc_rating))
    else:
        epc_avg.append(0)
avg_epc_tuple=list(zip(list_starting_withZ,epc_avg))
street_name_epc=pd.DataFrame(avg_epc_tuple, columns=['street_name','average_epc'])
street_name_epc
# Out:
# CPU times: user 411 ms, sys: 22.9 ms, total: 434 ms
# Wall time: 1min 1s
#       street_name average_epc
# 0  Zenoria Street           D
# 1    Zander Court           C
# 2     Zennor Road           0
# 3   Zangwill Road           D
# 4  Zoffany Street           B
# 5     Zoar Street           0
# 6    Zealand Road           D
# 7  Zetland Street           D

# %%
# %%time
#get the results of EPC ratings for all the street names in London FINAL:
#first create a list of URLs for scraping
list_epc_urls=[]
epc_url='https://find-energy-certificate.digital.communities.gov.uk/find-a-certificate/search-by-street-name-and-town?street_name='
town_url='&town=London'
epc_avg=[]

for street_name in list_london_street_names:
    url_street_name=street_name.replace(' ','+')
    list_epc_urls.append(epc_url+url_street_name+town_url)

    #iterate through
for url in list_epc_urls:
    
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'lxml')
    epc_ads=soup.find_all('tr', class_ = 'govuk-table__row')
    
    epc_id_ad = 0
    flat_address_final=[]
    epc_rating=[]
    for k in range(len(epc_ads)):
        ad = epc_ads[k]
        flat_address = ad.find_all('a', class_='govuk-link')
  
        if len(flat_address) !=0:
            flat_address_final.append(flat_address[0].get_text(strip=True))
        else: 
            continue

        epc_rating.append(ad.find_all('td', class_='govuk-table__cell')[0].get_text(strip=True))

        epc_id_ad += 1
    if len(epc_rating)!=0:
        epc_avg.append(mode(epc_rating))
    else:
        epc_avg.append(0)
avg_epc_tuple=list(zip(list_london_street_names,epc_avg))
street_name_epc=pd.DataFrame(avg_epc_tuple, columns=['street_name','average_epc'])
street_name_epc
